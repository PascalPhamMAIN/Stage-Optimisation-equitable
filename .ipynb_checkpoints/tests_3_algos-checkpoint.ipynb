# %%
nb_tests = 5

time_approx_o_sum = 0
time_exact_o_sum = 0
ratio_approx_o_sum = 0
time_approx_c_sum = 0
time_exact_c_sum = 0
ratio_approx_c_sum = 0
min_max_val_o1 = 1 # on cherche le plus petit sur les nb_tests pour C et O (en fait les 2 c'est tjrs la meme valeur)
min_max_val_c1 = 1

for i in range(nb_tests):
    print("Test numéro :", i+1)
    # %run arrondi_iteratif.ipynb
    time_approx_o_sum += time_max
    time_exact_o_sum += time_exact
    ratio_approx_o_sum += ratio_max_o
    time_approx_c_sum += time_approx_c
    time_exact_c_sum += time_exact_c
    ratio_approx_c_sum += ratio_max_c
    if min_max_val_o < min_max_val_o1:
        min_max_val_o1 = min_max_val_o
    if min_max_val_c < min_max_val_c1:
        min_max_val_c1 = min_max_val_c

time_approx_o_moy = time_approx_o_sum/nb_tests
time_exact_o_moy = time_exact_o_sum/nb_tests
ratio_approx_o_moy = ratio_approx_o_sum/nb_tests

time_approx_c_moy = time_approx_c_sum/nb_tests
time_exact_c_moy = time_exact_c_sum/nb_tests
ratio_approx_c_moy = ratio_approx_c_sum/nb_tests

print("\n-----RESULTATS FINAUX-----")
print("O-MIP : Temps moyen avec algo approché :", time_approx_o_moy)
print("C-MIP : Temps moyen avec algo approché :", time_approx_c_moy)
print("O-MIP : Temps moyen avec algo exact :", time_exact_o_moy)
print("C-MIP : Temps moyen avec algo exact :", time_exact_c_moy)
print("O-MIP : Ratio moyen de", ratio_approx_o_moy)
print("C-MIP : Ratio moyen de", ratio_approx_c_moy)
print("min_max_val(O) sur l'ensemble des tests :", min_max_val_o1)
print("min_max_val(C) sur l'ensemble des tests :", min_max_val_c1)
# Out:
# Test numéro : 1
# Set parameter Username
# Set parameter LicenseID to value 2652794
# Academic license - for non-commercial use only - expires 2026-04-15
# Nombre d'itérations prises par Gurobi : 724.0
# time_approx(O) : 0.6747901439666748
# val_approx_o : 27922.000000
# min_max_val(O) : 0.2617443770395577
# Cout total : 2831.0
# time_exact(O) : 0.9166603088378906
# val_exact_o : 26755.000000
# time_exact(C) : 0.8992621898651123
# val_exact_c : 26755.000000
# Nombre d'itérations prises par Gurobi : 671.0
# time_approx(C) : 0.4119412899017334
# val_approx_c : 27922.000000
# min_max_val(C) : 0.2617443770395576
# Cout total : 2831.0
# O-MIP, Ratio de 1.0436180153242385
# C-MIP, Ratio de 1.0436180153242385
# ------
# Test numéro : 2
# Nombre d'itérations prises par Gurobi : 685.0
# time_approx(O) : 0.6480600833892822
# val_approx_o : 25227.000000
# min_max_val(O) : 0.4245810055865922
# Cout total : 2596.0
# time_exact(O) : 0.8802986145019531
# val_exact_o : 24772.000000
# time_exact(C) : 0.6741118431091309
# val_exact_c : 24772.000000
# Nombre d'itérations prises par Gurobi : 576.0
# time_approx(C) : 0.39183974266052246
# val_approx_c : 25227.000000
# min_max_val(C) : 0.4245810055865922
# Cout total : 2596.0
# O-MIP, Ratio de 1.0183675117067656
# C-MIP, Ratio de 1.0183675117067656
# ------
# Test numéro : 3
# Nombre d'itérations prises par Gurobi : 700.0
# time_approx(O) : 0.6531176567077637
# val_approx_o : 25673.000000
# min_max_val(O) : 0.47412680489466935
# Cout total : 2785.0
# time_exact(O) : 1.4913678169250488
# val_exact_o : 25424.000000
# time_exact(C) : 0.9975318908691406
# val_exact_c : 25424.000000
# Nombre d'itérations prises par Gurobi : 506.0
# time_approx(C) : 0.4017455577850342
# val_approx_c : 25673.000000
# min_max_val(C) : 0.47412680489466924
# Cout total : 2785.0
# O-MIP, Ratio de 1.009793895531781
# C-MIP, Ratio de 1.009793895531781
# ------
# Test numéro : 4
# Nombre d'itérations prises par Gurobi : 764.0
# time_approx(O) : 0.6138074398040771
# val_approx_o : 22668.000000
# min_max_val(O) : 0.3821097587419509
# Cout total : 2516.0
# time_exact(O) : 1.2145273685455322
# val_exact_o : 22079.000000
# time_exact(C) : 1.0908217430114746
# val_exact_c : 22079.000000
# Nombre d'itérations prises par Gurobi : 688.0
# time_approx(C) : 0.40357112884521484
# val_approx_c : 22668.000000
# min_max_val(C) : 0.38210975874195063
# Cout total : 2516.0
# O-MIP, Ratio de 1.0266769328321028
# C-MIP, Ratio de 1.0266769328321028
# ------
# Test numéro : 5
# Nombre d'itérations prises par Gurobi : 567.0
# time_approx(O) : 0.6370368003845215
# val_approx_o : 14573.000000
# min_max_val(O) : 0.5675675675675675
# Cout total : 1506.0
# time_exact(O) : 0.5882701873779297
# val_exact_o : 14548.000000
# time_exact(C) : 0.5742638111114502
# val_exact_c : 14548.000000
# Nombre d'itérations prises par Gurobi : 531.0
# time_approx(C) : 0.3994567394256592
# val_approx_c : 14573.000000
# min_max_val(C) : 0.5675675675675675
# Cout total : 1506.0
# O-MIP, Ratio de 1.0017184492713775
# C-MIP, Ratio de 1.0017184492713775
# ------
#
# -----RESULTATS FINAUX-----
# O-MIP : Temps moyen avec algo approché : 0.6453624248504639
# C-MIP : Temps moyen avec algo approché : 0.40171089172363283
# O-MIP : Temps moyen avec algo exact : 1.0182248592376708
# C-MIP : Temps moyen avec algo exact : 0.8471982955932618
# O-MIP : Ratio moyen de 1.020034960933253
# C-MIP : Ratio moyen de 1.020034960933253
# min_max_val(O) sur l'ensemble des tests : 0.2617443770395577
# min_max_val(C) sur l'ensemble des tests : 0.2617443770395576
