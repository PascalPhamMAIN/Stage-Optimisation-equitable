# %%
# Cellule utilisée pour comparer les temps des différents algorithmes utilisant le modèle compact/exponentiel

nb_tests = 30

time_approx_o_sum = 0
time_exact_o_sum = 0
ratio_approx_o_sum = 0

time_approx_c_sum = 0
time_exact_c_sum = 0
ratio_approx_c_sum = 0

time_approx_3e_sum = 0
time_approx_3e_sans_sep_sum = 0
time_exact_3e_sum = 0
ratio_approx_3e_sum = 0

min_min_max_val_o1 = 1
min_min_max_val_c1 = 1
min_min_max_val_3e_v2 = 1
sum_min_max_val_o1 = 0
sum_min_max_val_c1 = 0
sum_min_max_val_3e_v2 = 0

sum_it_frac_o = 0
sum_it_frac_c = 0
sum_it_frac_3e = 0

for i in range(nb_tests):
    print("Test numéro :", i+1)
    # %run affectation_couple.ipynb
    time_approx_o_sum += time_approx_o
    time_exact_o_sum += time_exact_o
    ratio_approx_o_sum += ratio_o
    
    time_approx_c_sum += time_approx_c
    time_exact_c_sum += time_exact_c
    ratio_approx_c_sum += ratio_c
    
    time_approx_3e_sum += time_approx_3e_v2
    time_approx_3e_sans_sep_sum += time_3e_sans_separation
    time_exact_3e_sum += time_3e_exact
    ratio_approx_3e_sum += ratio_3e

    sum_min_max_val_o1 += min_max_val_o
    sum_min_max_val_c1 += min_max_val_c
    sum_min_max_val_3e_v2 += min_max_val_3e_v2

    sum_it_frac_o += it_frac_o
    sum_it_frac_c += it_frac_c
    sum_it_frac_3e += it_frac_3e
    
    if min_max_val_o < min_min_max_val_o1:
        min_min_max_val_o1 = min_max_val_o
    if min_max_val_c < min_min_max_val_c1:
        min_min_max_val_c1 = min_max_val_c
    if min_max_val_3e_v2 < min_min_max_val_3e_v2:
        min_min_max_val_3e_v2 = min_max_val_3e_v2

time_approx_o_moy = time_approx_o_sum/nb_tests
time_exact_o_moy = time_exact_o_sum/nb_tests
ratio_approx_o_moy = ratio_approx_o_sum/nb_tests

time_approx_c_moy = time_approx_c_sum/nb_tests
time_exact_c_moy = time_exact_c_sum/nb_tests
ratio_approx_c_moy = ratio_approx_c_sum/nb_tests

time_approx_3e_moy = time_approx_3e_sum/nb_tests
time_approx_3e_sans_sep_moy = time_approx_3e_sans_sep_sum/nb_tests
time_exact_3e_moy = time_exact_3e_sum/nb_tests
ratio_approx_3e_moy = ratio_approx_3e_sum/nb_tests

moy_min_max_val_o1 = sum_min_max_val_o1/nb_tests
moy_min_max_val_c1 = sum_min_max_val_c1/nb_tests
moy_min_max_val_3e_v2 = sum_min_max_val_3e_v2/nb_tests

moy_it_frac_o = sum_it_frac_o/nb_tests
moy_it_frac_c = sum_it_frac_c/nb_tests
moy_it_frac_3e = sum_it_frac_3e/nb_tests

print("\n-----RESULTATS FINAUX-----")
print("O-MIP : Temps moyen avec algo approché :", time_approx_o_moy)
print("C-MIP : Temps moyen avec algo approché :", time_approx_c_moy)
print("3e mod : Temps moyen avec algo approché :", time_approx_3e_moy)
print("3e mod : Temps moyen avec algo approché sans probleme de séparation :", time_approx_3e_sans_sep_moy)

print("O-MIP : Temps moyen avec algo exact :", time_exact_o_moy)
print("C-MIP : Temps moyen avec algo exact :", time_exact_c_moy)
print("3e mod : Temps moyen avec algo exact :", time_exact_3e_moy)
print()

print("O-MIP : Ratio moyen de", ratio_approx_o_moy)
print("C-MIP : Ratio moyen de", ratio_approx_c_moy)
print("3e mod : Ratio moyen de", ratio_approx_3e_moy)
print()

print("min min_max_val(O) sur l'ensemble des tests :", min_min_max_val_o1)
print("min min_max_val(C) sur l'ensemble des tests :", min_min_max_val_c1)
print("min min_max_val(3e) sur l'ensemble des tests :", min_min_max_val_3e_v2)

print("moy min_max_val(O) sur l'ensemble des tests :", moy_min_max_val_o1)
print("moy min_max_val(C) sur l'ensemble des tests :", moy_min_max_val_c1)
print("moy min_max_val(3e) sur l'ensemble des tests :", moy_min_max_val_3e_v2)

print("moy it_frac(O) sur l'ensemble des tests :", moy_it_frac_o)
print("moy it_frac(C) sur l'ensemble des tests :", moy_it_frac_c)
print("moy it_frac(3e) sur l'ensemble des tests :", moy_it_frac_3e)
# Out:
# Test numéro : 1
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1021.0
# time_exact(O) : 0.21265935897827148
# val_exact(O) : 22888.0
# time_approx(O) : 0.17625999450683594
# val_approx(O): 23349.0
# min_max_val(O): 0.5844155844155844
# it_frac(O) = 9
# time_exact(C) : 0.18545961380004883
# val_exact(C) : 22783.000000
# time_approx(C) : 0.10748076438903809
# val_approx(C) : 23317.000000
# min_max_val(C) : 0.5210643015521067
# it_frac(C) : 9
# 116
# 1.0 1 8
# 116
# 1.0 3 1
# 147
# 0.9999999999999998 14 11
# 154
# 0.9328859060402664 2 3
# 166
# 0.9483985765124547 10 9
# 167
# 0.9765840220385675 9 2
# 167
# 0.8889597021310808 0 7
# 167
# 0.9554060775532985 11 14
# 175
# 0.7263475771938278 8 13
# 180
# 0.783068783068783 6 15
# 188
# 0.542654028436019 4 12
# 199
# 0.801418439716312 15 10
# 206
# 1.0 5 0
# 206
# 1.0 7 4
# 207
# 1.0 12 6
# 207
# 1.0 13 5
# 207
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 207
# time_approx_3e_v2 : 0.23457098007202148
# min_max_val_3e_v2 : 0.542654028436019
# val_new_mod_v2 : 11674.5
# 2*val_new_mod : 23349.000000
# it_frac(3e) = 10
# time_3e_exact : 74.65967798233032
# val_new_mod_dyn : 22888.0
# time_3e_sans_separation : 6.973182678222656
# val_new_mod_dyn_sans_separation : 23349.0
# O-MIP, Ratio de : 1.0201415588954912
# C-MIP, Ratio de : 1.02343852872756
# 3e mod, Ratio de : 1.0201415588954912
# ------
# Test numéro : 2
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 983.0
# time_exact(O) : 0.1334700584411621
# val_exact(O) : 26342.0
# time_approx(O) : 0.1727616786956787
# val_approx(O): 26342.0
# min_max_val(O): 0.6
# it_frac(O) = 1
# time_exact(C) : 0.06336450576782227
# val_exact(C) : 26155.000000
# time_approx(C) : 0.0931551456451416
# val_approx(C) : 26204.000000
# min_max_val(C) : 0.6620689655172415
# it_frac(C) : 2
# 47
# 1.0 0 7
# 48
# 1.0 2 4
# 53
# 1.0 3 1
# 57
# 1.0 4 10
# 59
# 1.0 6 0
# 60
# 1.0 7 6
# 60
# 1.0 8 2
# 64
# 1.0 9 14
# 64
# 1.0 10 5
# 65
# 1.0 11 13
# 65
# 1.0 13 12
# 65
# 1.0 14 8
# 66
# 0.8387096774193549 5 11
# 67
# 1.0 1 15
# 67
# 1.0 12 9
# 67
# 1.0 15 3
# 67
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 67
# time_approx_3e_v2 : 0.16199207305908203
# min_max_val_3e_v2 : 0.8387096774193549
# val_new_mod_v2 : 13240.5
# 2*val_new_mod : 26481.000000
# it_frac(3e) = 1
# time_3e_exact : 10.274291038513184
# val_new_mod_dyn : 26342.0
# time_3e_sans_separation : 5.71591854095459
# val_new_mod_dyn_sans_separation : 26342.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0018734467597017
# 3e mod, Ratio de : 1.005276744362615
# ------
# Test numéro : 3
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1028.0
# time_exact(O) : 0.14487528800964355
# val_exact(O) : 15200.0
# time_approx(O) : 0.17017531394958496
# val_approx(O): 15200.0
# min_max_val(O): 0.8805031446540881
# it_frac(O) = 4
# time_exact(C) : 0.06727361679077148
# val_exact(C) : 14966.000000
# time_approx(C) : 0.09019923210144043
# val_approx(C) : 14966.000000
# min_max_val(C) : 0.8752327746741155
# it_frac(C) : 5
# 74
# 1.0 5 0
# 84
# 1.0 8 1
# 86
# 1.0 3 7
# 92
# 1.0 0 5
# 100
# 1.0 1 3
# 106
# 1.0 2 8
# 113
# 1.0 6 15
# 117
# 1.0 7 6
# 123
# 1.0 9 14
# 125
# 1.0 4 13
# 128
# 1.0 10 10
# 129
# 1.0 11 9
# 132
# 1.0 12 4
# 136
# 1.0 13 11
# 136
# 1.0 14 12
# 136
# 1.0 15 2
# 136
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 136
# time_approx_3e_v2 : 0.1771564483642578
# min_max_val_3e_v2 : 1
# val_new_mod_v2 : 7600.0
# 2*val_new_mod : 15200.000000
# it_frac(3e) = 0
# time_3e_exact : 16.680959224700928
# val_new_mod_dyn : 15200.0
# time_3e_sans_separation : 5.8641932010650635
# val_new_mod_dyn_sans_separation : 15200.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 4
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 996.0
# time_exact(O) : 0.24398589134216309
# val_exact(O) : 29503.0
# time_approx(O) : 0.18955421447753906
# val_approx(O): 29503.0
# min_max_val(O): 0.6324435318275154
# it_frac(O) = 10
# time_exact(C) : 0.24979162216186523
# val_exact(C) : 29302.000000
# time_approx(C) : 0.0987398624420166
# val_approx(C) : 29302.000000
# min_max_val(C) : 0.6183574879227054
# it_frac(C) : 10
# 114
# 1.0 7 2
# 147
# 1.0 5 11
# 194
# 0.9222685357599796 12 9
# 201
# 0.9063030192184333 1 3
# 202
# 0.8452403459184931 13 15
# 228
# 0.8729240823760188 15 8
# 231
# 0.7723880597014923 2 7
# 239
# 0.7547114301098545 4 13
# 246
# 1.0 8 1
# 248
# 0.8020895448221029 3 14
# 255
# 0.8860673922807845 14 5
# 259
# 0.6080402010050252 0 10
# 265
# 1.0 6 0
# 267
# 1.0 11 12
# 267
# 0.8108504398826981 9 4
# 273
# 1.0 10 6
# 273
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 273
# time_approx_3e_v2 : 0.2779514789581299
# min_max_val_3e_v2 : 0.6080402010050252
# val_new_mod_v2 : 14751.5
# 2*val_new_mod : 29503.000000
# it_frac(3e) = 10
# time_3e_exact : 75.43202877044678
# val_new_mod_dyn : 29503.0
# time_3e_sans_separation : 6.8987956047058105
# val_new_mod_dyn_sans_separation : 29503.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 5
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1046.0
# time_exact(O) : 0.14004993438720703
# val_exact(O) : 26960.0
# time_approx(O) : 0.16866302490234375
# val_approx(O): 26960.0
# min_max_val(O): 0.9828962371721779
# it_frac(O) = 1
# time_exact(C) : 0.061536550521850586
# val_exact(C) : 26838.000000
# time_approx(C) : 0.0874471664428711
# val_approx(C) : 26838.000000
# min_max_val(C) : 0.9925883694412773
# it_frac(C) : 1
# 54
# 1.0 0 1
# 60
# 1.0 1 9
# 60
# 1.0 2 8
# 63
# 1.0 4 4
# 67
# 1.0 5 10
# 71
# 1.0 6 13
# 77
# 1.0 7 7
# 77
# 1.0 3 14
# 79
# 1.0 8 11
# 84
# 1.0 9 0
# 84
# 1.0 10 2
# 89
# 1.0 11 5
# 89
# 1.0 12 15
# 90
# 1.0 13 3
# 90
# 1.0 14 12
# 94
# 1.0 15 6
# 94
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 94
# time_approx_3e_v2 : 0.15433764457702637
# min_max_val_3e_v2 : 1
# val_new_mod_v2 : 13480.0
# 2*val_new_mod : 26960.000000
# it_frac(3e) = 0
# time_3e_exact : 10.495085000991821
# val_new_mod_dyn : 26960.0
# time_3e_sans_separation : 5.894043684005737
# val_new_mod_dyn_sans_separation : 26960.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 6
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 968.0
# time_exact(O) : 0.22582340240478516
# val_exact(O) : 27104.0
# time_approx(O) : 0.17630815505981445
# val_approx(O): 27154.0
# min_max_val(O): 0.6328671328671331
# it_frac(O) = 9
# time_exact(C) : 0.14163780212402344
# val_exact(C) : 27034.000000
# time_approx(C) : 0.0870962142944336
# val_approx(C) : 27036.000000
# min_max_val(C) : 0.5959183673469388
# it_frac(C) : 10
# 70
# 1.0 0 10
# 90
# 0.9438039564445149 15 1
# 98
# 0.9972677595628415 8 4
# 99
# 0.9900865267661558 7 14
# 108
# 0.9089935760171306 3 5
# 117
# 0.9041811846689896 13 7
# 120
# 0.8678466954715378 1 8
# 121
# 0.8630769230769231 10 6
# 130
# 0.9644191330070295 4 2
# 130
# 1.0 6 12
# 130
# 0.6386861313868606 2 0
# 131
# 1.0 5 3
# 131
# 1.0 9 15
# 131
# 1.0 11 13
# 133
# 1.0 12 9
# 133
# 1.0 14 11
# 133
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 133
# time_approx_3e_v2 : 0.18484830856323242
# min_max_val_3e_v2 : 0.6386861313868606
# val_new_mod_v2 : 13577.0
# 2*val_new_mod : 27154.000000
# it_frac(3e) = 9
# time_3e_exact : 74.57844018936157
# val_new_mod_dyn : 27104.0
# time_3e_sans_separation : 6.516523122787476
# val_new_mod_dyn_sans_separation : 27154.0
# O-MIP, Ratio de : 1.001844746162928
# C-MIP, Ratio de : 1.0000739809129244
# 3e mod, Ratio de : 1.001844746162928
# ------
# Test numéro : 7
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1049.0
# time_exact(O) : 0.193129301071167
# val_exact(O) : 30325.0
# time_approx(O) : 0.19075393676757812
# val_approx(O): 32298.0
# min_max_val(O): 0.5992647058823528
# it_frac(O) = 9
# time_exact(C) : 0.1342456340789795
# val_exact(C) : 29964.000000
# time_approx(C) : 0.09971761703491211
# val_approx(C) : 29964.000000
# min_max_val(C) : 0.7722593115549647
# it_frac(C) : 9
# 88
# 1.0 15 8
# 129
# 0.887351598173518 3 4
# 142
# 0.9358726161446174 1 5
# 158
# 0.974537497513415 9 2
# 171
# 0.9551820728291319 8 3
# 184
# 1.0 10 15
# 195
# 0.9449612403100779 0 13
# 197
# 0.9769230769230769 7 10
# 204
# 0.9565891472868219 14 0
# 208
# 1.0 2 9
# 209
# 1.0 5 6
# 210
# 1.0 6 7
# 210
# 1.0 12 1
# 211
# 1.0 13 14
# 211
# 0.9140625 4 11
# 211
# 1.0 11 12
# 211
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 211
# time_approx_3e_v2 : 0.23951935768127441
# min_max_val_3e_v2 : 0.887351598173518
# val_new_mod_v2 : 15162.5
# 2*val_new_mod : 30325.000000
# it_frac(3e) = 8
# time_3e_exact : 75.96568465232849
# val_new_mod_dyn : 30325.0
# time_3e_sans_separation : 7.489187002182007
# val_new_mod_dyn_sans_separation : 32551.0
# O-MIP, Ratio de : 1.0650618301731245
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 8
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1004.0
# time_exact(O) : 0.25368452072143555
# val_exact(O) : 21900.0
# time_approx(O) : 0.1789078712463379
# val_approx(O): 21900.0
# min_max_val(O): 0.6037735849056604
# it_frac(O) = 10
# time_exact(C) : 0.1299898624420166
# val_exact(C) : 21339.000000
# time_approx(C) : 0.09332633018493652
# val_approx(C) : 21339.000000
# min_max_val(C) : 0.7443868739205527
# it_frac(C) : 8
# 100
# 1.0 3 2
# 137
# 1.0 1 11
# 142
# 0.9977933464276407 4 5
# 155
# 1.0 6 13
# 156
# 1.0 11 1
# 183
# 0.9736732029975893 15 15
# 212
# 0.9711684370257967 13 8
# 212
# 0.9555503267700418 0 7
# 216
# 1.0000000000000002 8 12
# 217
# 1.0 9 4
# 217
# 0.9736842105263163 7 3
# 217
# 0.880195599022005 14 0
# 224
# 0.9985074626865672 2 10
# 225
# 0.889937106918239 5 9
# 227
# 1.0 10 6
# 227
# 1.0 12 14
# 228
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 228
# time_approx_3e_v2 : 0.24737834930419922
# min_max_val_3e_v2 : 0.880195599022005
# val_new_mod_v2 : 10950.0
# 2*val_new_mod : 21900.000000
# it_frac(3e) = 8
# time_3e_exact : 50.94888496398926
# val_new_mod_dyn : 21900.0
# time_3e_sans_separation : 6.261244535446167
# val_new_mod_dyn_sans_separation : 21900.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 9
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1049.0
# time_exact(O) : 0.25710344314575195
# val_exact(O) : 20334.0
# time_approx(O) : 0.17160797119140625
# val_approx(O): 20334.0
# min_max_val(O): 0.6648250900699906
# it_frac(O) = 8
# time_exact(C) : 0.13311338424682617
# val_exact(C) : 20296.000000
# time_approx(C) : 0.09525918960571289
# val_approx(C) : 20377.000000
# min_max_val(C) : 0.792391058929781
# it_frac(C) : 9
# 111
# 1.0 1 14
# 177
# 1.0 9 5
# 220
# 0.931 12 2
# 232
# 0.8941965548558072 7 3
# 232
# 0.8599088838268794 0 4
# 243
# 0.956923076923077 3 9
# 246
# 1.0 11 6
# 246
# 0.7652675653594772 13 0
# 251
# 0.7602739726027401 4 1
# 252
# 1.0 8 11
# 254
# 0.8344907407407407 2 13
# 257
# 1.0 5 12
# 259
# 1.0 15 8
# 259
# 0.6010928961748632 6 10
# 260
# 1.0 10 7
# 262
# 1.0 14 15
# 263
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 263
# time_approx_3e_v2 : 0.2721984386444092
# min_max_val_3e_v2 : 0.6010928961748632
# val_new_mod_v2 : 10167.0
# 2*val_new_mod : 20334.000000
# it_frac(3e) = 8
# time_3e_exact : 74.07887434959412
# val_new_mod_dyn : 20334.0
# time_3e_sans_separation : 6.306257963180542
# val_new_mod_dyn_sans_separation : 20334.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0039909341742215
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 10
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1019.0
# time_exact(O) : 0.22231483459472656
# val_exact(O) : 27315.0
# time_approx(O) : 0.12604308128356934
# val_approx(O): 27315.0
# min_max_val(O): 0.5897435897435898
# it_frac(O) = 5
# time_exact(C) : 0.08243489265441895
# val_exact(C) : 27069.000000
# time_approx(C) : 0.0923759937286377
# val_approx(C) : 27190.000000
# min_max_val(C) : 0.5814917127071824
# it_frac(C) : 4
# 97
# 1.0 2 8
# 115
# 1.0 3 1
# 125
# 1.0 5 6
# 130
# 1.0 10 13
# 156
# 1.0 11 14
# 172
# 0.7678060474827924 8 11
# 188
# 0.7886643105412262 6 0
# 206
# 1.0 0 10
# 211
# 1.0 14 4
# 211
# 0.5413533834586466 1 9
# 229
# 1.0 4 3
# 230
# 1.0 15 2
# 241
# 0.8815789473684214 12 7
# 246
# 1.0 7 15
# 246
# 1.0 9 5
# 250
# 1.0 13 12
# 251
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 251
# time_approx_3e_v2 : 0.24577856063842773
# min_max_val_3e_v2 : 0.5413533834586466
# val_new_mod_v2 : 13657.5
# 2*val_new_mod : 27315.000000
# it_frac(3e) = 4
# time_3e_exact : 72.99686932563782
# val_new_mod_dyn : 27315.0
# time_3e_sans_separation : 6.138018369674683
# val_new_mod_dyn_sans_separation : 27315.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0044700579999262
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 11
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1005.0
# time_exact(O) : 0.1804807186126709
# val_exact(O) : 32306.0
# time_approx(O) : 0.18486404418945312
# val_approx(O): 35041.0
# min_max_val(O): 0.5718849840255591
# it_frac(O) = 9
# time_exact(C) : 0.12868380546569824
# val_exact(C) : 32089.000000
# time_approx(C) : 0.09246158599853516
# val_approx(C) : 32089.000000
# min_max_val(C) : 0.7211267605633802
# it_frac(C) : 7
# 104
# 1.0 3 3
# 146
# 1.0 2 15
# 160
# 1.0 4 9
# 179
# 1.0 14 10
# 182
# 0.9788505396735158 12 7
# 191
# 0.9381270903010034 9 14
# 192
# 0.8907766990291267 0 2
# 196
# 0.9507042253521126 6 12
# 201
# 1.0 10 1
# 204
# 0.9532224532224531 5 13
# 204
# 1.0 15 8
# 205
# 0.9238807046213746 8 6
# 207
# 0.6847826086956521 7 5
# 209
# 1.0 1 11
# 209
# 1.0 11 0
# 212
# 1.0 13 4
# 212
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 212
# time_approx_3e_v2 : 0.24111437797546387
# min_max_val_3e_v2 : 0.6847826086956521
# val_new_mod_v2 : 16288.0
# 2*val_new_mod : 32576.000000
# it_frac(3e) = 7
# time_3e_exact : 72.80522394180298
# val_new_mod_dyn : 32306.0
# time_3e_sans_separation : 6.529005527496338
# val_new_mod_dyn_sans_separation : 35041.0
# O-MIP, Ratio de : 1.084659196434099
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.008357580635176
# ------
# Test numéro : 12
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1056.0
# time_exact(O) : 0.1730961799621582
# val_exact(O) : 31009.0
# time_approx(O) : 0.17421722412109375
# val_approx(O): 31009.0
# min_max_val(O): 0.5393258426966292
# it_frac(O) = 4
# time_exact(C) : 0.09020709991455078
# val_exact(C) : 30910.000000
# time_approx(C) : 0.08534812927246094
# val_approx(C) : 30910.000000
# min_max_val(C) : 0.5674157303370787
# it_frac(C) : 5
# 65
# 1.0 3 13
# 71
# 1.0 4 0
# 78
# 1.0000000000000033 14 4
# 85
# 1.0 5 5
# 104
# 1.0 9 1
# 116
# 1.0 15 12
# 117
# 0.9352409638554217 0 10
# 117
# 0.9588112617309695 6 11
# 117
# 1.0 13 15
# 128
# 0.9601451884809491 7 9
# 130
# 1.0 1 8
# 130
# 0.5505617977528093 12 2
# 136
# 1.0 2 6
# 139
# 1.0 8 14
# 143
# 1.0 10 7
# 144
# 1.0 11 3
# 144
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 144
# time_approx_3e_v2 : 0.19623756408691406
# min_max_val_3e_v2 : 0.5505617977528093
# val_new_mod_v2 : 15504.5
# 2*val_new_mod : 31009.000000
# it_frac(3e) = 4
# time_3e_exact : 70.8780345916748
# val_new_mod_dyn : 31009.0
# time_3e_sans_separation : 6.1295294761657715
# val_new_mod_dyn_sans_separation : 31009.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 13
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1030.0
# time_exact(O) : 0.16826510429382324
# val_exact(O) : 30436.0
# time_approx(O) : 0.18706369400024414
# val_approx(O): 30436.0
# min_max_val(O): 0.5546962450391777
# it_frac(O) = 9
# time_exact(C) : 0.12923383712768555
# val_exact(C) : 30369.000000
# time_approx(C) : 0.09623384475708008
# val_approx(C) : 30369.000000
# min_max_val(C) : 0.5680933852140078
# it_frac(C) : 8
# 102
# 1.0 4 0
# 127
# 1.0 11 8
# 132
# 0.9185899921688624 7 13
# 156
# 0.9721428571428572 10 5
# 164
# 0.91304347826087 1 15
# 175
# 1.0 14 3
# 175
# 0.9731371684076331 9 10
# 175
# 0.8243988440838832 6 12
# 181
# 0.6746031746031746 0 14
# 188
# 1.0 2 7
# 188
# 1.0 3 2
# 188
# 0.9588607594936709 5 9
# 188
# 1.0 8 4
# 188
# 1.0 12 6
# 189
# 1.0 13 11
# 189
# 1.0 15 1
# 189
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 189
# time_approx_3e_v2 : 0.21222233772277832
# min_max_val_3e_v2 : 0.6746031746031746
# val_new_mod_v2 : 15476.5
# 2*val_new_mod : 30953.000000
# it_frac(3e) = 7
# time_3e_exact : 70.84183120727539
# val_new_mod_dyn : 30436.0
# time_3e_sans_separation : 7.65755033493042
# val_new_mod_dyn_sans_separation : 30436.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.016986463398607
# ------
# Test numéro : 14
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1044.0
# time_exact(O) : 0.28968214988708496
# val_exact(O) : 29281.0
# time_approx(O) : 0.24483156204223633
# val_approx(O): 29281.0
# min_max_val(O): 0.6121495327102804
# it_frac(O) = 8
# time_exact(C) : 0.15301275253295898
# val_exact(C) : 29228.000000
# time_approx(C) : 0.08619904518127441
# val_approx(C) : 29228.000000
# min_max_val(C) : 0.6136363636363636
# it_frac(C) : 7
# 102
# 1.0 1 11
# 134
# 1.0 4 8
# 134
# 0.9816211736387678 11 12
# 146
# 0.9281376518218623 3 1
# 159
# 1.0 12 9
# 167
# 0.9601577669891412 2 3
# 174
# 1.0 5 2
# 176
# 0.8715953307392996 0 6
# 184
# 1.0000000000000002 9 14
# 190
# 1.0 14 4
# 193
# 1.0 15 7
# 195
# 0.9993939393939395 10 5
# 198
# 1.0 8 13
# 198
# 0.6136363636363636 6 0
# 203
# 1.0 7 15
# 203
# 1.0 13 10
# 204
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 204
# time_approx_3e_v2 : 0.423947811126709
# min_max_val_3e_v2 : 0.6136363636363636
# val_new_mod_v2 : 14640.5
# 2*val_new_mod : 29281.000000
# it_frac(3e) = 6
# time_3e_exact : 74.0673303604126
# val_new_mod_dyn : 29281.0
# time_3e_sans_separation : 6.420095205307007
# val_new_mod_dyn_sans_separation : 29281.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 15
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 974.0
# time_exact(O) : 0.15433645248413086
# val_exact(O) : 31126.0
# time_approx(O) : 0.1708390712738037
# val_approx(O): 31126.0
# min_max_val(O): 0.7814569536423841
# it_frac(O) = 3
# time_exact(C) : 0.06917762756347656
# val_exact(C) : 30933.000000
# time_approx(C) : 0.0911567211151123
# val_approx(C) : 30933.000000
# min_max_val(C) : 0.6991902115282197
# it_frac(C) : 4
# 68
# 1.0 0 12
# 76
# 1.0 3 8
# 81
# 1.0 4 7
# 83
# 1.0 5 5
# 89
# 1.0 7 14
# 89
# 1.0 10 6
# 94
# 0.9183908045977295 15 13
# 105
# 1.0 2 1
# 106
# 1.0 6 9
# 106
# 1.0 13 4
# 113
# 1.0 14 2
# 113
# 0.6539735099337749 9 11
# 118
# 1.0 12 15
# 123
# 0.8254437869822485 1 0
# 123
# 1.0 8 10
# 123
# 1.0 11 3
# 123
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 123
# time_approx_3e_v2 : 0.19237947463989258
# min_max_val_3e_v2 : 0.6539735099337749
# val_new_mod_v2 : 15563.0
# 2*val_new_mod : 31126.000000
# it_frac(3e) = 3
# time_3e_exact : 71.00341367721558
# val_new_mod_dyn : 31126.0
# time_3e_sans_separation : 6.010745286941528
# val_new_mod_dyn_sans_separation : 31126.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 16
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1033.0
# time_exact(O) : 0.18198728561401367
# val_exact(O) : 17157.0
# time_approx(O) : 0.17190217971801758
# val_approx(O): 17157.0
# min_max_val(O): 0.5415162454873647
# it_frac(O) = 5
# time_exact(C) : 0.0646505355834961
# val_exact(C) : 17085.000000
# time_approx(C) : 0.08924126625061035
# val_approx(C) : 17085.000000
# min_max_val(C) : 0.5221238938053098
# it_frac(C) : 3
# 67
# 1.0 0 4
# 77
# 1.0 1 5
# 80
# 1.0 10 8
# 85
# 1.0 15 1
# 89
# 0.833381802841934 2 14
# 91
# 0.5941558441558441 3 11
# 106
# 1.0 4 13
# 110
# 1.0 6 12
# 113
# 1.0 13 3
# 113
# 0.9818181818181818 8 15
# 113
# 0.9945504087193461 5 6
# 113
# 1.0 14 10
# 113
# 0.8850000000000009 11 9
# 116
# 1.0 7 0
# 118
# 1.0 9 7
# 119
# 1.0 12 2
# 120
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 120
# time_approx_3e_v2 : 0.19123506546020508
# min_max_val_3e_v2 : 0.5941558441558441
# val_new_mod_v2 : 8578.5
# 2*val_new_mod : 17157.000000
# it_frac(3e) = 5
# time_3e_exact : 70.13825058937073
# val_new_mod_dyn : 17157.0
# time_3e_sans_separation : 6.184286832809448
# val_new_mod_dyn_sans_separation : 17157.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 17
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1004.0
# time_exact(O) : 0.12703299522399902
# val_exact(O) : 27812.0
# time_approx(O) : 0.16555309295654297
# val_approx(O): 27812.0
# min_max_val(O): 1
# it_frac(O) = 0
# time_exact(C) : 0.04511141777038574
# val_exact(C) : 27695.000000
# time_approx(C) : 0.08446264266967773
# val_approx(C) : 27695.000000
# min_max_val(C) : 1
# it_frac(C) : 0
# 31
# 1.0 0 11
# 37
# 1.0 1 6
# 43
# 1.0 2 7
# 43
# 1.0 3 2
# 44
# 1.0 4 0
# 47
# 1.0 5 12
# 53
# 1.0 6 9
# 57
# 1.0 7 3
# 60
# 1.0 8 13
# 65
# 1.0 9 10
# 70
# 1.0 10 4
# 72
# 1.0 11 8
# 73
# 1.0 12 5
# 73
# 1.0 13 15
# 73
# 1.0 14 14
# 73
# 1.0 15 1
# 73
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 73
# time_approx_3e_v2 : 0.14946341514587402
# min_max_val_3e_v2 : 1
# val_new_mod_v2 : 13906.0
# 2*val_new_mod : 27812.000000
# it_frac(3e) = 0
# time_3e_exact : 7.466143608093262
# val_new_mod_dyn : 27812.0
# time_3e_sans_separation : 5.673607587814331
# val_new_mod_dyn_sans_separation : 27812.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 18
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1025.0
# time_exact(O) : 0.20098614692687988
# val_exact(O) : 19868.0
# time_approx(O) : 0.17170333862304688
# val_approx(O): 19868.0
# min_max_val(O): 0.5135135135135135
# it_frac(O) = 7
# time_exact(C) : 0.11789298057556152
# val_exact(C) : 19806.000000
# time_approx(C) : 0.09099483489990234
# val_approx(C) : 19977.000000
# min_max_val(C) : 0.5045537340619307
# it_frac(C) : 7
# 79
# 1.0 0 1
# 109
# 1.0 4 15
# 133
# 1.0 14 14
# 140
# 0.9114391143911439 1 11
# 142
# 0.9511749295934566 3 7
# 147
# 1.0 6 12
# 147
# 0.8416779618821061 12 8
# 156
# 1.0000000000000004 7 6
# 157
# 1.0 8 2
# 161
# 1.0 9 9
# 161
# 1.0 10 3
# 168
# 1.0 13 13
# 169
# 0.5567567567567568 2 5
# 178
# 1.0 5 0
# 180
# 1.0 11 4
# 180
# 1.0 15 10
# 181
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 181
# time_approx_3e_v2 : 0.21740984916687012
# min_max_val_3e_v2 : 0.5567567567567568
# val_new_mod_v2 : 9934.0
# 2*val_new_mod : 19868.000000
# it_frac(3e) = 4
# time_3e_exact : 75.22449088096619
# val_new_mod_dyn : 19868.0
# time_3e_sans_separation : 8.094148874282837
# val_new_mod_dyn_sans_separation : 19868.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0086337473492881
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 19
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1040.0
# time_exact(O) : 0.26233720779418945
# val_exact(O) : 26126.0
# time_approx(O) : 0.17233896255493164
# val_approx(O): 26126.0
# min_max_val(O): 0.6806083650190113
# it_frac(O) = 7
# time_exact(C) : 0.11363887786865234
# val_exact(C) : 26038.000000
# time_approx(C) : 0.10670948028564453
# val_approx(C) : 26038.000000
# min_max_val(C) : 0.7034220532319392
# it_frac(C) : 7
# 105
# 1.0 8 12
# 127
# 1.0 4 7
# 148
# 1.0 6 6
# 162
# 0.8791429742154824 13 5
# 195
# 0.9933665555901134 0 15
# 200
# 0.9033917977817902 10 13
# 205
# 0.884030418250951 7 3
# 213
# 1.0 1 0
# 213
# 1.0 3 11
# 218
# 1.0 11 4
# 221
# 1.0 14 10
# 223
# 1.0 15 14
# 225
# 0.9381443298969072 2 1
# 231
# 1.0 5 9
# 231
# 1.0 9 8
# 232
# 1.0 12 2
# 237
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 237
# time_approx_3e_v2 : 0.3183553218841553
# min_max_val_3e_v2 : 0.8791429742154824
# val_new_mod_v2 : 13063.0
# 2*val_new_mod : 26126.000000
# it_frac(3e) = 5
# time_3e_exact : 80.43505120277405
# val_new_mod_dyn : 26126.0
# time_3e_sans_separation : 6.2129902839660645
# val_new_mod_dyn_sans_separation : 26126.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 20
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1064.0
# time_exact(O) : 0.12532496452331543
# val_exact(O) : 19739.0
# time_approx(O) : 0.15926527976989746
# val_approx(O): 19739.0
# min_max_val(O): 1
# it_frac(O) = 0
# time_exact(C) : 0.04839897155761719
# val_exact(C) : 19670.000000
# time_approx(C) : 0.0876922607421875
# val_approx(C) : 19670.000000
# min_max_val(C) : 0.9871134020618557
# it_frac(C) : 1
# 42
# 1.0 0 2
# 42
# 1.0 1 11
# 45
# 1.0 2 9
# 50
# 1.0 3 8
# 54
# 1.0 4 14
# 57
# 1.0 5 4
# 62
# 1.0 6 7
# 65
# 1.0 7 15
# 65
# 1.0 8 1
# 65
# 1.0 9 3
# 68
# 1.0 10 6
# 72
# 1.0 11 0
# 76
# 1.0 12 12
# 80
# 1.0 13 10
# 80
# 1.0 14 5
# 84
# 1.0 15 13
# 84
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 84
# time_approx_3e_v2 : 0.14462757110595703
# min_max_val_3e_v2 : 1
# val_new_mod_v2 : 9869.5
# 2*val_new_mod : 19739.000000
# it_frac(3e) = 0
# time_3e_exact : 7.725902080535889
# val_new_mod_dyn : 19739.0
# time_3e_sans_separation : 5.571744918823242
# val_new_mod_dyn_sans_separation : 19739.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 21
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1037.0
# time_exact(O) : 0.2165215015411377
# val_exact(O) : 26196.0
# time_approx(O) : 0.1739182472229004
# val_approx(O): 26196.0
# min_max_val(O): 0.70160719327386
# it_frac(O) = 8
# time_exact(C) : 0.10224461555480957
# val_exact(C) : 25471.000000
# time_approx(C) : 0.08817028999328613
# val_approx(C) : 25471.000000
# min_max_val(C) : 0.6868131868131868
# it_frac(C) : 5
# 87
# 1.0 8 3
# 95
# 1.0 10 12
# 95
# 1.0 11 13
# 99
# 1.0 3 7
# 103
# 1.0 13 8
# 111
# 0.924901185770751 5 1
# 115
# 1.0 12 4
# 123
# 0.9509606690777557 14 0
# 124
# 0.9511064845442417 15 15
# 124
# 0.7053571428571433 6 9
# 128
# 1.0 0 6
# 131
# 1.0 1 14
# 131
# 1.0 2 10
# 137
# 1.0 4 2
# 137
# 1.0 7 11
# 137
# 1.0 9 5
# 137
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 137
# time_approx_3e_v2 : 0.19676876068115234
# min_max_val_3e_v2 : 0.7053571428571433
# val_new_mod_v2 : 13098.0
# 2*val_new_mod : 26196.000000
# it_frac(3e) = 4
# time_3e_exact : 50.12318205833435
# val_new_mod_dyn : 26196.0
# time_3e_sans_separation : 6.052655220031738
# val_new_mod_dyn_sans_separation : 26196.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 22
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1030.0
# time_exact(O) : 0.1686708927154541
# val_exact(O) : 25486.0
# time_approx(O) : 0.18665194511413574
# val_approx(O): 25486.0
# min_max_val(O): 0.7257383966244726
# it_frac(O) = 8
# time_exact(C) : 0.08793902397155762
# val_exact(C) : 25231.000000
# time_approx(C) : 0.08490872383117676
# val_approx(C) : 25231.000000
# min_max_val(C) : 0.7619047619047619
# it_frac(C) : 8
# 99
# 1.0 0 8
# 110
# 1.0 1 1
# 118
# 1.0 2 4
# 132
# 1.0 4 7
# 132
# 0.9344059405940595 11 2
# 133
# 1.0 14 0
# 144
# 0.9635416666666666 7 9
# 144
# 0.9119433198380567 8 6
# 150
# 0.8357525167842335 5 14
# 151
# 0.9204772575858512 15 11
# 153
# 0.8505434782608697 3 5
# 156
# 1.0 10 12
# 161
# 0.8924050632911393 6 3
# 167
# 0.9594272076372315 12 10
# 168
# 0.9429347826086957 9 13
# 168
# 1.0 13 15
# 168
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 168
# time_approx_3e_v2 : 0.2162625789642334
# min_max_val_3e_v2 : 0.8357525167842335
# val_new_mod_v2 : 12743.0
# 2*val_new_mod : 25486.000000
# it_frac(3e) = 9
# time_3e_exact : 70.48727869987488
# val_new_mod_dyn : 25486.0
# time_3e_sans_separation : 6.14486289024353
# val_new_mod_dyn_sans_separation : 25486.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 23
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1054.0
# time_exact(O) : 0.2829723358154297
# val_exact(O) : 30648.0
# time_approx(O) : 0.18722128868103027
# val_approx(O): 30865.0
# min_max_val(O): 0.5719073852910583
# it_frac(O) = 7
# time_exact(C) : 0.15718388557434082
# val_exact(C) : 29863.000000
# time_approx(C) : 0.0944979190826416
# val_approx(C) : 29863.000000
# min_max_val(C) : 0.5488764456863766
# it_frac(C) : 8
# 84
# 1.0 5 14
# 86
# 1.0 6 13
# 92
# 1.0 0 6
# 95
# 1.0 2 3
# 113
# 1.0 3 9
# 116
# 1.0 7 11
# 130
# 1.0 4 1
# 133
# 1.0 9 8
# 137
# 1.0 13 10
# 138
# 0.8878281622911695 1 7
# 146
# 1.0 15 0
# 146
# 0.9059405940594036 14 5
# 151
# 0.7149253731343285 11 15
# 159
# 0.9296977660972405 12 4
# 161
# 1.0 8 2
# 161
# 1.0 10 12
# 161
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 161
# time_approx_3e_v2 : 0.23125886917114258
# min_max_val_3e_v2 : 0.7149253731343285
# val_new_mod_v2 : 15432.5
# 2*val_new_mod : 30865.000000
# it_frac(3e) = 4
# time_3e_exact : 72.86463761329651
# val_new_mod_dyn : 30648.0
# time_3e_sans_separation : 6.3031463623046875
# val_new_mod_dyn_sans_separation : 30865.0
# O-MIP, Ratio de : 1.0070803967632471
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0070803967632471
# ------
# Test numéro : 24
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1000.0
# time_exact(O) : 0.20437216758728027
# val_exact(O) : 27712.0
# time_approx(O) : 0.17402887344360352
# val_approx(O): 27712.0
# min_max_val(O): 0.5919540229885059
# it_frac(O) = 7
# time_exact(C) : 0.19323348999023438
# val_exact(C) : 26939.000000
# time_approx(C) : 0.09014773368835449
# val_approx(C) : 26939.000000
# min_max_val(C) : 0.6220095693779903
# it_frac(C) : 7
# 93
# 1.0 12 11
# 99
# 1.0 13 14
# 124
# 1.0 14 15
# 153
# 1.0 11 0
# 157
# 0.9369834710743802 4 6
# 157
# 0.7742574257425742 10 13
# 171
# 0.6780821917808222 1 4
# 182
# 1.0 2 9
# 182
# 1.0000000000000002 5 5
# 183
# 1.0 3 2
# 186
# 1.0 6 3
# 193
# 1.0 7 10
# 193
# 1.0 9 7
# 193
# 0.7191780821917808 0 1
# 198
# 1.0 8 12
# 202
# 1.0 15 8
# 205
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 205
# time_approx_3e_v2 : 0.22528624534606934
# min_max_val_3e_v2 : 0.6780821917808222
# val_new_mod_v2 : 13940.5
# 2*val_new_mod : 27881.000000
# it_frac(3e) = 4
# time_3e_exact : 71.70692563056946
# val_new_mod_dyn : 27712.0
# time_3e_sans_separation : 6.62582540512085
# val_new_mod_dyn_sans_separation : 27712.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.006098441108545
# ------
# Test numéro : 25
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1005.0
# time_exact(O) : 0.19126176834106445
# val_exact(O) : 27195.0
# time_approx(O) : 0.1761610507965088
# val_approx(O): 27304.0
# min_max_val(O): 0.6257473286344242
# it_frac(O) = 8
# time_exact(C) : 0.16028404235839844
# val_exact(C) : 27102.000000
# time_approx(C) : 0.08140110969543457
# val_approx(C) : 27102.000000
# min_max_val(C) : 0.6468768879533856
# it_frac(C) : 10
# 98
# 1.0 3 12
# 127
# 1.0 8 3
# 155
# 0.735856827423489 14 2
# 172
# 0.7591765920776439 7 11
# 189
# 1.0 10 4
# 192
# 1.0 15 1
# 202
# 0.6549999999999998 1 10
# 210
# 0.9930332261521972 5 15
# 210
# 0.6850000000000016 11 7
# 215
# 1.0 2 8
# 215
# 0.5310924369747901 0 14
# 221
# 0.9873417721518988 4 13
# 223
# 1.0 6 9
# 223
# 1.0 9 6
# 223
# 1.0 12 5
# 227
# 1.0 13 0
# 227
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 227
# time_approx_3e_v2 : 0.2564847469329834
# min_max_val_3e_v2 : 0.5310924369747901
# val_new_mod_v2 : 13705.0
# 2*val_new_mod : 27410.000000
# it_frac(3e) = 7
# time_3e_exact : 75.38693642616272
# val_new_mod_dyn : 27195.0
# time_3e_sans_separation : 6.557800054550171
# val_new_mod_dyn_sans_separation : 27304.0
# O-MIP, Ratio de : 1.0040080897223755
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0079058650487223
# ------
# Test numéro : 26
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1027.0
# time_exact(O) : 0.20319604873657227
# val_exact(O) : 22351.0
# time_approx(O) : 0.17269062995910645
# val_approx(O): 22351.0
# min_max_val(O): 0.6140350877192982
# it_frac(O) = 6
# time_exact(C) : 0.09617972373962402
# val_exact(C) : 22252.000000
# time_approx(C) : 0.0796051025390625
# val_approx(C) : 22252.000000
# min_max_val(C) : 0.5987599645704164
# it_frac(C) : 5
# 72
# 1.0 3 9
# 73
# 1.0 0 12
# 77
# 1.0 2 3
# 77
# 1.0 4 14
# 83
# 1.0 7 0
# 84
# 1.0 9 10
# 90
# 1.0 10 5
# 94
# 0.7115384615384718 5 15
# 98
# 1.0 1 8
# 102
# 1.0 6 2
# 105
# 1.0 8 13
# 107
# 1.0000000000000004 13 11
# 111
# 1.0 15 1
# 115
# 0.9345454545454546 11 7
# 123
# 1.0 12 6
# 124
# 1.0 14 4
# 124
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 124
# time_approx_3e_v2 : 0.1869819164276123
# min_max_val_3e_v2 : 0.7115384615384718
# val_new_mod_v2 : 11175.5
# 2*val_new_mod : 22351.000000
# it_frac(3e) = 2
# time_3e_exact : 71.93011236190796
# val_new_mod_dyn : 22351.0
# time_3e_sans_separation : 6.182225465774536
# val_new_mod_dyn_sans_separation : 22351.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 27
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1024.0
# time_exact(O) : 0.20141291618347168
# val_exact(O) : 31915.0
# time_approx(O) : 0.1766796112060547
# val_approx(O): 31984.0
# min_max_val(O): 0.7129186602870814
# it_frac(O) = 12
# time_exact(C) : 0.18311476707458496
# val_exact(C) : 31865.000000
# time_approx(C) : 0.09837102890014648
# val_approx(C) : 31893.000000
# min_max_val(C) : 0.5789473684210525
# it_frac(C) : 12
# 92
# 0.9940416608473202 3 9
# 92
# 0.8771177208306065 14 11
# 129
# 1.0 11 5
# 143
# 0.8772683752275815 5 1
# 153
# 1.0 4 8
# 177
# 0.8969879518072289 8 2
# 178
# 0.8792540076541022 13 13
# 179
# 0.8853227861560735 0 6
# 188
# 0.8839009287925695 6 12
# 190
# 0.7620095693779899 7 3
# 198
# 0.7249621043245653 15 7
# 211
# 0.9420212765957446 1 10
# 214
# 1.0 2 4
# 214
# 0.9888297872340426 9 14
# 218
# 0.7261029411764706 10 0
# 218
# 1.0 12 15
# 219
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 219
# time_approx_3e_v2 : 0.24948811531066895
# min_max_val_3e_v2 : 0.7249621043245653
# val_new_mod_v2 : 15992.0
# 2*val_new_mod : 31984.000000
# it_frac(3e) = 12
# time_3e_exact : 73.59269094467163
# val_new_mod_dyn : 31915.0
# time_3e_sans_separation : 7.180102348327637
# val_new_mod_dyn_sans_separation : 31984.0
# O-MIP, Ratio de : 1.0021619927933574
# C-MIP, Ratio de : 1.0008787070453475
# 3e mod, Ratio de : 1.0021619927933574
# ------
# Test numéro : 28
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1019.0
# time_exact(O) : 0.12726163864135742
# val_exact(O) : 22622.0
# time_approx(O) : 0.16548871994018555
# val_approx(O): 22622.0
# min_max_val(O): 1
# it_frac(O) = 0
# time_exact(C) : 0.06270909309387207
# val_exact(C) : 22507.000000
# time_approx(C) : 0.08479833602905273
# val_approx(C) : 22507.000000
# min_max_val(C) : 0.8963317384370015
# it_frac(C) : 1
# 37
# 1.0 0 0
# 40
# 1.0 1 7
# 42
# 1.0 2 9
# 47
# 1.0 3 4
# 51
# 1.0 4 13
# 55
# 1.0 5 2
# 56
# 1.0 6 6
# 56
# 1.0 7 15
# 62
# 1.0 8 5
# 63
# 1.0 9 11
# 65
# 1.0 10 8
# 66
# 1.0 11 3
# 66
# 1.0 12 12
# 66
# 1.0 13 10
# 66
# 1.0 14 1
# 66
# 1.0 15 14
# 66
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 66
# time_approx_3e_v2 : 0.14426088333129883
# min_max_val_3e_v2 : 1
# val_new_mod_v2 : 11311.0
# 2*val_new_mod : 22622.000000
# it_frac(3e) = 0
# time_3e_exact : 8.587834596633911
# val_new_mod_dyn : 22622.0
# time_3e_sans_separation : 5.588300704956055
# val_new_mod_dyn_sans_separation : 22622.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 29
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1022.0
# time_exact(O) : 0.18358516693115234
# val_exact(O) : 24004.0
# time_approx(O) : 0.16819119453430176
# val_approx(O): 24004.0
# min_max_val(O): 0.7165354330708661
# it_frac(O) = 3
# time_exact(C) : 0.06615996360778809
# val_exact(C) : 23897.000000
# time_approx(C) : 0.052986860275268555
# val_approx(C) : 23897.000000
# min_max_val(C) : 0.7268518518518519
# it_frac(C) : 3
# 70
# 1.0 3 10
# 82
# 1.0 4 11
# 96
# 1.0 9 2
# 114
# 1.0 0 15
# 118
# 1.0 5 6
# 118
# 1.0 11 5
# 118
# 1.0 12 9
# 122
# 1.0 15 8
# 129
# 0.8547896912229513 13 4
# 141
# 0.7243589743589736 2 1
# 147
# 1.0 1 13
# 147
# 1.0 6 14
# 147
# 1.0 7 12
# 147
# 1.0 8 0
# 147
# 1.0 10 7
# 147
# 1.0 14 3
# 147
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 147
# time_approx_3e_v2 : 0.17260122299194336
# min_max_val_3e_v2 : 0.7243589743589736
# val_new_mod_v2 : 12002.0
# 2*val_new_mod : 24004.000000
# it_frac(3e) = 2
# time_3e_exact : 32.767439126968384
# val_new_mod_dyn : 24004.0
# time_3e_sans_separation : 5.775479793548584
# val_new_mod_dyn_sans_separation : 24004.0
# O-MIP, Ratio de : 1.0
# C-MIP, Ratio de : 1.0
# 3e mod, Ratio de : 1.0
# ------
# Test numéro : 30
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 1083.0
# time_exact(O) : 0.4082658290863037
# val_exact(O) : 31766.0
# time_approx(O) : 0.17867040634155273
# val_approx(O): 32414.0
# min_max_val(O): 0.5431034482758621
# it_frac(O) = 8
# time_exact(C) : 0.2917139530181885
# val_exact(C) : 31611.000000
# time_approx(C) : 0.09571576118469238
# val_approx(C) : 32211.000000
# min_max_val(C) : 0.5989010989010988
# it_frac(C) : 10
# 90
# 1.0 0 11
# 111
# 1.0 1 14
# 111
# 1.0 6 8
# 111
# 1.0 10 13
# 125
# 0.9146651591461922 13 1
# 128
# 0.8361492848002076 4 10
# 130
# 0.778592375366572 2 0
# 132
# 0.9745199852253924 8 5
# 138
# 0.6709263835499422 3 15
# 142
# 1.0 12 7
# 143
# 0.9586834733893531 14 2
# 147
# 0.865845857914646 9 12
# 150
# 0.744413407821229 5 4
# 151
# 1.0 7 9
# 151
# 1.0 11 6
# 151
# 1.0 15 3
# 151
# -1 -1 -1
# Nombre de contraintes ajoutées dans le modèle : 151
# time_approx_3e_v2 : 0.21320176124572754
# min_max_val_3e_v2 : 0.6709263835499422
# val_new_mod_v2 : 15981.0
# 2*val_new_mod : 31962.000000
# it_frac(3e) = 8
# time_3e_exact : 69.38120317459106
# val_new_mod_dyn : 31766.0
# time_3e_sans_separation : 6.718053340911865
# val_new_mod_dyn_sans_separation : 32414.0
# O-MIP, Ratio de : 1.0203991689227476
# C-MIP, Ratio de : 1.0189807345544273
# 3e mod, Ratio de : 1.006170118995152
# ------
#
# -----RESULTATS FINAUX-----
# O-MIP : Temps moyen avec algo approché : 0.1761105219523112
# C-MIP : Temps moyen avec algo approché : 0.09019667307535807
# 3e mod : Temps moyen avec algo approché : 0.21917731761932374
# 3e mod : Temps moyen avec algo approché sans probleme de séparation : 6.388984020551046
# O-MIP : Temps moyen avec algo exact : 0.2026048501332601
# C-MIP : Temps moyen avec algo exact : 0.12032059828440349
# 3e mod : Temps moyen avec algo exact : 57.78415694236755
#
# O-MIP : Ratio moyen de 1.0068452326622457
# C-MIP : Ratio moyen de 1.0020780045841133
# 3e mod : Ratio moyen de 1.002734130272128
#
# min min_max_val(O) sur l'ensemble des tests : 0.5135135135135135
# min min_max_val(C) sur l'ensemble des tests : 0.5045537340619307
# min min_max_val(3e) sur l'ensemble des tests : 0.5310924369747901
# moy min_max_val(O) sur l'ensemble des tests : 0.6789810413279148
# moy min_max_val(C) sur l'ensemble des tests : 0.6902902543974692
# moy min_max_val(3e) sur l'ensemble des tests : 0.7347564043376473
# moy it_frac(O) sur l'ensemble des tests : 6.166666666666667
# moy it_frac(C) sur l'ensemble des tests : 6.166666666666667
# moy it_frac(3e) sur l'ensemble des tests : 5.033333333333333

# %%
# Crée un tableau dans un fichier ods contenant toutes les informations sauvegardées

nb_tests = 30

time_approx_o_sum = 0
time_exact_o_sum = 0
ratio_approx_o_sum = 0

time_approx_c_sum = 0
time_exact_c_sum = 0
ratio_approx_c_sum = 0

time_approx_3e_sum = 0
#time_exact_3e_sum = 0
ratio_approx_3e_sum = 0

min_min_max_val_o1 = 1
min_min_max_val_c1 = 1
min_min_max_val_3e_v2 = 1
sum_min_max_val_o1 = 0
sum_min_max_val_c1 = 0
sum_min_max_val_3e_v2 = 0

sum_it_frac_o = 0
sum_it_frac_c = 0
sum_it_frac_3e = 0

for i in range(nb_tests):
    print("Test numéro :", i+1)
    # %run affectation_couple.ipynb
    time_approx_o_sum += time_approx_o
    time_exact_o_sum += time_exact_o
    ratio_approx_o_sum += ratio_o
    time_approx_c_sum += time_approx_c
    time_exact_c_sum += time_exact_c
    ratio_approx_c_sum += ratio_c
    time_approx_3e_sum += time_approx_3e_v2
    #time_exact_3e_sum += time_exact_3e
    ratio_approx_3e_sum += ratio_3e

    sum_min_max_val_o1 += min_max_val_o
    sum_min_max_val_c1 += min_max_val_c
    sum_min_max_val_3e_v2 += min_max_val_3e_v2

    sum_it_frac_o += it_frac_o
    sum_it_frac_c += it_frac_c
    sum_it_frac_3e += it_frac_3e
    
    if min_max_val_o < min_min_max_val_o1:
        min_min_max_val_o1 = min_max_val_o
    if min_max_val_c < min_min_max_val_c1:
        min_min_max_val_c1 = min_max_val_c
    if min_max_val_3e_v2 < min_min_max_val_3e_v2:
        min_min_max_val_3e_v2 = min_max_val_3e_v2

time_approx_o_moy = time_approx_o_sum/nb_tests
time_exact_o_moy = time_exact_o_sum/nb_tests
ratio_approx_o_moy = ratio_approx_o_sum/nb_tests

time_approx_c_moy = time_approx_c_sum/nb_tests
time_exact_c_moy = time_exact_c_sum/nb_tests
ratio_approx_c_moy = ratio_approx_c_sum/nb_tests

time_approx_3e_moy = time_approx_3e_sum/nb_tests
#time_exact_3e_moy = time_exact_3e_sum/nb_tests
ratio_approx_3e_moy = ratio_approx_3e_sum/nb_tests

moy_min_max_val_o1 = sum_min_max_val_o1/nb_tests
moy_min_max_val_c1 = sum_min_max_val_c1/nb_tests
moy_min_max_val_3e_v2 = sum_min_max_val_3e_v2/nb_tests

moy_it_frac_o = sum_it_frac_o/nb_tests
moy_it_frac_c = sum_it_frac_c/nb_tests
moy_it_frac_3e = sum_it_frac_3e/nb_tests

print("\n-----RESULTATS FINAUX-----")
print("O-MIP : Temps moyen avec algo approché :", time_approx_o_moy)
print("C-MIP : Temps moyen avec algo approché :", time_approx_c_moy)
print("3e mod : Temps moyen avec algo approché :", time_approx_3e_moy)

print("O-MIP : Temps moyen avec algo exact :", time_exact_o_moy)
print("C-MIP : Temps moyen avec algo exact :", time_exact_c_moy)
print()

print("O-MIP : Ratio moyen de", ratio_approx_o_moy)
print("C-MIP : Ratio moyen de", ratio_approx_c_moy)
print("3e mod : Ratio moyen de", ratio_approx_3e_moy)
print()

print("min min_max_val(O) sur l'ensemble des tests :", min_min_max_val_o1)
print("min min_max_val(C) sur l'ensemble des tests :", min_min_max_val_c1)
print("min min_max_val(3e) sur l'ensemble des tests :", min_min_max_val_3e_v2)

print("moy min_max_val(O) sur l'ensemble des tests :", moy_min_max_val_o1)
print("moy min_max_val(C) sur l'ensemble des tests :", moy_min_max_val_c1)
print("moy min_max_val(3e) sur l'ensemble des tests :", moy_min_max_val_3e_v2)

print("moy it_frac(O) sur l'ensemble des tests :", moy_it_frac_o)
print("moy it_frac(C) sur l'ensemble des tests :", moy_it_frac_c)
print("moy it_frac(3e) sur l'ensemble des tests :", moy_it_frac_3e)

#import csv
import pandas as pd

#row = [time_approx_o_moy, time_approx_c_moy, time_approx_3e_moy, time_exact_o_moy, time_exact_c_moy, ratio_approx_o_moy, ratio_approx_c_moy, ratio_approx_3e_moy, min_min_max_val_o1, min_min_max_val_c1, min_min_max_val_3e_v2, moy_min_max_val_o1, moy_min_max_val_c1, moy_min_max_val_3e_v2, moy_it_frac_o, moy_it_frac_c, moy_it_frac_3e]

#with open("affectation_couple_data.csv", "a", newline="", encoding="utf-8") as f:
#    writer = csv.writer(f, delimiter=";")
#    writer.writerow(row)

filename = "affectation_couple_data.ods"

try:
    df = pd.read_excel(filename, engine="odf")
except FileNotFoundError:
    df = pd.DataFrame(columns=["n/m", "k", "time_approx_o_moy", "time_approx_c_moy", "time_approx_3e_moy",
                               "time_exact_o_moy", "time_exact_c_moy", "ratio_approx_o_moy",
                               "ratio_approx_c_moy", "ratio_approx_3e_moy", "min_min_max_val_o1",
                               "min_min_max_val_c1", "min_min_max_val_3e_v2", "moy_min_max_val_o1",
                               "moy_min_max_val_c1", "moy_min_max_val_3e_v2", "moy_it_frac_o",
                               "moy_it_frac_c", "moy_it_frac_3e"])

row = [round(val, 4) for val in [
    n, nb_ressources, time_approx_o_moy, time_approx_c_moy, time_approx_3e_moy, time_exact_o_moy, time_exact_c_moy,
    ratio_approx_o_moy, ratio_approx_c_moy, ratio_approx_3e_moy, min_min_max_val_o1, min_min_max_val_c1,
    min_min_max_val_3e_v2, moy_min_max_val_o1, moy_min_max_val_c1, moy_min_max_val_3e_v2, moy_it_frac_o,
    moy_it_frac_c, moy_it_frac_3e
]]

df.loc[len(df)] = row

# Sauvegarder au format ODS
df.to_excel(filename, index=False, engine="odf")
# Out:
# Test numéro : 1
# Set parameter Username
# Set parameter LicenseID to value 2652794
# Academic license - for non-commercial use only - expires 2026-04-15
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 370.0
# 33
# 34
# 35
# 35
# 37
# 40
# 40
# 40
# 40
# 40
# 40
# Nombre de contraintes ajoutées dans le modèle : 40
# time_approx_3e_v2 : 0.04776191711425781
# min_max_val_3e_v2 : 0.8016614745586708
# val_new_mod_v2 : 6317.0
# 2*val_new_mod : 12634.000000
# it_frac(3e) = 2
# ------
# Test numéro : 2
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 335.0
# 31
# 31
# 34
# 37
# 39
# 43
# 43
# 44
# 44
# 44
# 44
# Nombre de contraintes ajoutées dans le modèle : 44
# time_approx_3e_v2 : 0.04533863067626953
# min_max_val_3e_v2 : 0.6757246376811594
# val_new_mod_v2 : 7641.0
# 2*val_new_mod : 15282.000000
# it_frac(3e) = 3
# ------
# Test numéro : 3
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 342.0
# 30
# 40
# 41
# 52
# 52
# 52
# 55
# 55
# 55
# 55
# 55
# Nombre de contraintes ajoutées dans le modèle : 55
# time_approx_3e_v2 : 0.046529293060302734
# min_max_val_3e_v2 : 0.9147368421052631
# val_new_mod_v2 : 10103.5
# 2*val_new_mod : 20207.000000
# it_frac(3e) = 2
# ------
# Test numéro : 4
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 330.0
# 19
# 21
# 22
# 24
# 27
# 27
# 29
# 29
# 29
# 29
# 29
# Nombre de contraintes ajoutées dans le modèle : 29
# time_approx_3e_v2 : 0.028806209564208984
# min_max_val_3e_v2 : 1
# val_new_mod_v2 : 6638.0
# 2*val_new_mod : 13276.000000
# it_frac(3e) = 0
# ------
# Test numéro : 5
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 357.0
# 38
# 49
# 49
# 50
# 51
# 51
# 52
# 52
# 54
# 54
# 54
# Nombre de contraintes ajoutées dans le modèle : 54
# time_approx_3e_v2 : 0.0489804744720459
# min_max_val_3e_v2 : 0.9207317073170731
# val_new_mod_v2 : 9012.0
# 2*val_new_mod : 18024.000000
# it_frac(3e) = 2
# ------
# Test numéro : 6
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 321.0
# 46
# 50
# 50
# 55
# 56
# 63
# 66
# 66
# 68
# 68
# 68
# Nombre de contraintes ajoutées dans le modèle : 68
# time_approx_3e_v2 : 0.06242179870605469
# min_max_val_3e_v2 : 0.768987341772152
# val_new_mod_v2 : 10946.0
# 2*val_new_mod : 21892.000000
# it_frac(3e) = 3
# ------
# Test numéro : 7
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 333.0
# 45
# 51
# 51
# 51
# 51
# 51
# 54
# 55
# 57
# 58
# 58
# Nombre de contraintes ajoutées dans le modèle : 58
# time_approx_3e_v2 : 0.04623913764953613
# min_max_val_3e_v2 : 0.6015625
# val_new_mod_v2 : 6763.5
# 2*val_new_mod : 13527.000000
# it_frac(3e) = 2
# ------
# Test numéro : 8
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 345.0
# 47
# 60
# 61
# 66
# 73
# 77
# 77
# 79
# 79
# 81
# 83
# Nombre de contraintes ajoutées dans le modèle : 83
# time_approx_3e_v2 : 0.05145597457885742
# min_max_val_3e_v2 : 0.518361581920904
# val_new_mod_v2 : 7312.5
# 2*val_new_mod : 14625.000000
# it_frac(3e) = 3
# ------
# Test numéro : 9
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 344.0
# 37
# 41
# 51
# 51
# 52
# 55
# 57
# 57
# 57
# 57
# 57
# Nombre de contraintes ajoutées dans le modèle : 57
# time_approx_3e_v2 : 0.045063018798828125
# min_max_val_3e_v2 : 0.8046647230320703
# val_new_mod_v2 : 6630.0
# 2*val_new_mod : 13260.000000
# it_frac(3e) = 3
# ------
# Test numéro : 10
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 346.0
# 57
# 79
# 97
# 99
# 108
# 112
# 113
# 115
# 117
# 117
# 120
# Nombre de contraintes ajoutées dans le modèle : 120
# time_approx_3e_v2 : 0.06502795219421387
# min_max_val_3e_v2 : 0.6434210526315791
# val_new_mod_v2 : 8306.0
# 2*val_new_mod : 16612.000000
# it_frac(3e) = 4
# ------
# Test numéro : 11
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 356.0
# 28
# 29
# 29
# 31
# 32
# 33
# 33
# 33
# 33
# 33
# 33
# Nombre de contraintes ajoutées dans le modèle : 33
# time_approx_3e_v2 : 0.037155866622924805
# min_max_val_3e_v2 : 0.9574155653450808
# val_new_mod_v2 : 11778.5
# 2*val_new_mod : 23557.000000
# it_frac(3e) = 1
# ------
# Test numéro : 12
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 334.0
# 29
# 29
# 33
# 33
# 40
# 42
# 43
# 44
# 45
# 45
# 45
# Nombre de contraintes ajoutées dans le modèle : 45
# time_approx_3e_v2 : 0.04691672325134277
# min_max_val_3e_v2 : 0.6145833333333331
# val_new_mod_v2 : 11054.0
# 2*val_new_mod : 22108.000000
# it_frac(3e) = 3
# ------
# Test numéro : 13
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 336.0
# 41
# 48
# 48
# 50
# 54
# 55
# 61
# 62
# 63
# 63
# 64
# Nombre de contraintes ajoutées dans le modèle : 64
# time_approx_3e_v2 : 0.050832271575927734
# min_max_val_3e_v2 : 0.7530201342281879
# val_new_mod_v2 : 12474.5
# 2*val_new_mod : 24949.000000
# it_frac(3e) = 4
# ------
# Test numéro : 14
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 370.0
# 34
# 35
# 36
# 43
# 43
# 46
# 46
# 46
# 47
# 47
# 47
# Nombre de contraintes ajoutées dans le modèle : 47
# time_approx_3e_v2 : 0.05638289451599121
# min_max_val_3e_v2 : 0.5516759776536314
# val_new_mod_v2 : 7597.5
# 2*val_new_mod : 15195.000000
# it_frac(3e) = 3
# ------
# Test numéro : 15
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 364.0
# 26
# 26
# 32
# 32
# 33
# 33
# 34
# 34
# 34
# 34
# 34
# Nombre de contraintes ajoutées dans le modèle : 34
# time_approx_3e_v2 : 0.04103994369506836
# min_max_val_3e_v2 : 0.8459119496855346
# val_new_mod_v2 : 6554.5
# 2*val_new_mod : 13109.000000
# it_frac(3e) = 2
# ------
# Test numéro : 16
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 345.0
# 41
# 52
# 57
# 62
# 68
# 68
# 68
# 69
# 70
# 70
# 70
# Nombre de contraintes ajoutées dans le modèle : 70
# time_approx_3e_v2 : 0.06630325317382812
# min_max_val_3e_v2 : 0.9018837394361079
# val_new_mod_v2 : 8409.5
# 2*val_new_mod : 16819.000000
# it_frac(3e) = 2
# ------
# Test numéro : 17
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 340.0
# 39
# 43
# 44
# 55
# 56
# 57
# 59
# 61
# 61
# 61
# 63
# Nombre de contraintes ajoutées dans le modèle : 63
# time_approx_3e_v2 : 0.06664824485778809
# min_max_val_3e_v2 : 0.7424749163879598
# val_new_mod_v2 : 12637.5
# 2*val_new_mod : 25275.000000
# it_frac(3e) = 5
# ------
# Test numéro : 18
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 334.0
# 43
# 49
# 49
# 50
# 56
# 56
# 56
# 59
# 60
# 60
# 60
# Nombre de contraintes ajoutées dans le modèle : 60
# time_approx_3e_v2 : 0.0604252815246582
# min_max_val_3e_v2 : 0.8545331529093371
# val_new_mod_v2 : 9331.0
# 2*val_new_mod : 18662.000000
# it_frac(3e) = 2
# ------
# Test numéro : 19
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 343.0
# 29
# 36
# 42
# 45
# 46
# 50
# 53
# 53
# 56
# 59
# 61
# Nombre de contraintes ajoutées dans le modèle : 61
# time_approx_3e_v2 : 0.058976173400878906
# min_max_val_3e_v2 : 0.6670761670761703
# val_new_mod_v2 : 12977.5
# 2*val_new_mod : 25955.000000
# it_frac(3e) = 3
# ------
# Test numéro : 20
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 348.0
# 52
# 66
# 69
# 69
# 73
# 76
# 78
# 79
# 79
# 79
# 79
# Nombre de contraintes ajoutées dans le modèle : 79
# time_approx_3e_v2 : 0.07009577751159668
# min_max_val_3e_v2 : 0.5698113207547172
# val_new_mod_v2 : 4771.0
# 2*val_new_mod : 9542.000000
# it_frac(3e) = 3
# ------
# Test numéro : 21
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 344.0
# 18
# 19
# 22
# 26
# 30
# 30
# 30
# 30
# 32
# 32
# 32
# Nombre de contraintes ajoutées dans le modèle : 32
# time_approx_3e_v2 : 0.04764199256896973
# min_max_val_3e_v2 : 1
# val_new_mod_v2 : 7738.5
# 2*val_new_mod : 15477.000000
# it_frac(3e) = 0
# ------
# Test numéro : 22
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 340.0
# 27
# 30
# 34
# 40
# 43
# 43
# 48
# 51
# 51
# 51
# 51
# Nombre de contraintes ajoutées dans le modèle : 51
# time_approx_3e_v2 : 0.058713674545288086
# min_max_val_3e_v2 : 0.6554621848739496
# val_new_mod_v2 : 9740.0
# 2*val_new_mod : 19480.000000
# it_frac(3e) = 2
# ------
# Test numéro : 23
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 334.0
# 21
# 23
# 24
# 24
# 25
# 26
# 27
# 30
# 30
# 30
# 30
# Nombre de contraintes ajoutées dans le modèle : 30
# time_approx_3e_v2 : 0.05196857452392578
# min_max_val_3e_v2 : 0.8835616438356168
# val_new_mod_v2 : 11339.5
# 2*val_new_mod : 22679.000000
# it_frac(3e) = 2
# ------
# Test numéro : 24
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 346.0
# 46
# 62
# 68
# 68
# 74
# 76
# 77
# 79
# 79
# 79
# 79
# Nombre de contraintes ajoutées dans le modèle : 79
# time_approx_3e_v2 : 0.07128477096557617
# min_max_val_3e_v2 : 0.6513157894736845
# val_new_mod_v2 : 7575.5
# 2*val_new_mod : 15151.000000
# it_frac(3e) = 5
# ------
# Test numéro : 25
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 323.0
# 34
# 36
# 38
# 41
# 41
# 42
# 45
# 45
# 49
# 49
# 49
# Nombre de contraintes ajoutées dans le modèle : 49
# time_approx_3e_v2 : 0.05545973777770996
# min_max_val_3e_v2 : 0.9074844074844075
# val_new_mod_v2 : 7020.5
# 2*val_new_mod : 14041.000000
# it_frac(3e) = 2
# ------
# Test numéro : 26
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 324.0
# 37
# 37
# 37
# 39
# 40
# 42
# 46
# 48
# 48
# 48
# 48
# Nombre de contraintes ajoutées dans le modèle : 48
# time_approx_3e_v2 : 0.0546565055847168
# min_max_val_3e_v2 : 0.6304347826086961
# val_new_mod_v2 : 11569.0
# 2*val_new_mod : 23138.000000
# it_frac(3e) = 1
# ------
# Test numéro : 27
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 368.0
# 38
# 44
# 50
# 54
# 54
# 54
# 57
# 58
# 58
# 58
# 58
# Nombre de contraintes ajoutées dans le modèle : 58
# time_approx_3e_v2 : 0.060733795166015625
# min_max_val_3e_v2 : 0.8213660245183891
# val_new_mod_v2 : 7518.5
# 2*val_new_mod : 15037.000000
# it_frac(3e) = 2
# ------
# Test numéro : 28
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 332.0
# 36
# 41
# 42
# 42
# 42
# 45
# 45
# 46
# 46
# 46
# 46
# Nombre de contraintes ajoutées dans le modèle : 46
# time_approx_3e_v2 : 0.05694937705993652
# min_max_val_3e_v2 : 0.9588235294117646
# val_new_mod_v2 : 7617.5
# 2*val_new_mod : 15235.000000
# it_frac(3e) = 2
# ------
# Test numéro : 29
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 334.0
# 52
# 73
# 84
# 87
# 87
# 95
# 95
# 96
# 96
# 99
# 100
# Nombre de contraintes ajoutées dans le modèle : 100
# time_approx_3e_v2 : 0.07844734191894531
# min_max_val_3e_v2 : 0.5606684981684984
# val_new_mod_v2 : 11788.5
# 2*val_new_mod : 23577.000000
# it_frac(3e) = 7
# ------
# Test numéro : 30
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 369.0
# 41
# 45
# 50
# 53
# 60
# 60
# 69
# 69
# 69
# 71
# 71
# Nombre de contraintes ajoutées dans le modèle : 71
# time_approx_3e_v2 : 0.07116055488586426
# min_max_val_3e_v2 : 0.6084905660377359
# val_new_mod_v2 : 8079.0
# 2*val_new_mod : 16158.000000
# it_frac(3e) = 4
# ------

# %%
# Permet de compter le nombre de contraintes ajoutées

import pandas as pd
from affectation_couple_v2 import * # le fichier python et non ipynb

# RESTART LE KERNEL AVANT D'EXECUTER

nb_tests = 30
all_c_sat = []
for t in range(nb_tests):
    print("Test numéro :", t+1)
    c_sat = run_one_test()
    all_c_sat.append(c_sat)

# On suppose que chaque run retourne une liste de même longueur L
L = len(all_c_sat[0])
df = pd.DataFrame(all_c_sat,columns=[f"iter_{k}" for k in range(L)])
df.insert(0, "test", range(1, nb_tests+1))
df.to_excel("test_exp_data_4_4.ods", index=False, engine="odf")
print("OK")
#print(all_c_sat)
# Out:
# Test numéro : 1
# Set parameter Username
# Set parameter LicenseID to value 2652794
# Academic license - for non-commercial use only - expires 2026-04-15
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 92.0
# Iter 0 -> c_saturees = 8
# Iter 1 -> c_saturees = 9
# Iter 2 -> c_saturees = 9
# Iter 3 -> c_saturees = 10
# Iter 4 -> c_saturees = 10
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 2
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 91.0
# Iter 0 -> c_saturees = 5
# Iter 1 -> c_saturees = 5
# Iter 2 -> c_saturees = 5
# Iter 3 -> c_saturees = 5
# Iter 4 -> c_saturees = 5
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 3
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 91.0
# Iter 0 -> c_saturees = 10
# Iter 1 -> c_saturees = 10
# Iter 2 -> c_saturees = 10
# Iter 3 -> c_saturees = 10
# Iter 4 -> c_saturees = 10
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 4
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 94.0
# Iter 0 -> c_saturees = 9
# Iter 1 -> c_saturees = 11
# Iter 2 -> c_saturees = 12
# Iter 3 -> c_saturees = 13
# Iter 4 -> c_saturees = 14
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 5
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 92.0
# Iter 0 -> c_saturees = 7
# Iter 1 -> c_saturees = 7
# Iter 2 -> c_saturees = 7
# Iter 3 -> c_saturees = 7
# Iter 4 -> c_saturees = 7
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 6
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 83.0
# Iter 0 -> c_saturees = 7
# Iter 1 -> c_saturees = 9
# Iter 2 -> c_saturees = 9
# Iter 3 -> c_saturees = 9
# Iter 4 -> c_saturees = 9
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 7
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 90.0
# Iter 0 -> c_saturees = 5
# Iter 1 -> c_saturees = 5
# Iter 2 -> c_saturees = 5
# Iter 3 -> c_saturees = 5
# Iter 4 -> c_saturees = 5
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 8
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 87.0
# Iter 0 -> c_saturees = 7
# Iter 1 -> c_saturees = 7
# Iter 2 -> c_saturees = 7
# Iter 3 -> c_saturees = 7
# Iter 4 -> c_saturees = 7
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 9
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 76.0
# Iter 0 -> c_saturees = 7
# Iter 1 -> c_saturees = 7
# Iter 2 -> c_saturees = 7
# Iter 3 -> c_saturees = 7
# Iter 4 -> c_saturees = 7
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 10
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 70.0
# Iter 0 -> c_saturees = 5
# Iter 1 -> c_saturees = 5
# Iter 2 -> c_saturees = 6
# Iter 3 -> c_saturees = 6
# Iter 4 -> c_saturees = 6
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 11
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 95.0
# Iter 0 -> c_saturees = 4
# Iter 1 -> c_saturees = 4
# Iter 2 -> c_saturees = 4
# Iter 3 -> c_saturees = 4
# Iter 4 -> c_saturees = 4
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 12
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 92.0
# Iter 0 -> c_saturees = 6
# Iter 1 -> c_saturees = 6
# Iter 2 -> c_saturees = 9
# Iter 3 -> c_saturees = 9
# Iter 4 -> c_saturees = 9
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 13
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 95.0
# Iter 0 -> c_saturees = 5
# Iter 1 -> c_saturees = 5
# Iter 2 -> c_saturees = 5
# Iter 3 -> c_saturees = 5
# Iter 4 -> c_saturees = 5
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 14
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 90.0
# Iter 0 -> c_saturees = 8
# Iter 1 -> c_saturees = 12
# Iter 2 -> c_saturees = 13
# Iter 3 -> c_saturees = 14
# Iter 4 -> c_saturees = 14
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 15
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 85.0
# Iter 0 -> c_saturees = 6
# Iter 1 -> c_saturees = 6
# Iter 2 -> c_saturees = 6
# Iter 3 -> c_saturees = 6
# Iter 4 -> c_saturees = 6
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 16
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 81.0
# Iter 0 -> c_saturees = 9
# Iter 1 -> c_saturees = 10
# Iter 2 -> c_saturees = 10
# Iter 3 -> c_saturees = 10
# Iter 4 -> c_saturees = 10
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 17
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 85.0
# Iter 0 -> c_saturees = 6
# Iter 1 -> c_saturees = 6
# Iter 2 -> c_saturees = 6
# Iter 3 -> c_saturees = 6
# Iter 4 -> c_saturees = 6
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 18
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 71.0
# Iter 0 -> c_saturees = 9
# Iter 1 -> c_saturees = 13
# Iter 2 -> c_saturees = 13
# Iter 3 -> c_saturees = 13
# Iter 4 -> c_saturees = 13
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 19
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 99.0
# Iter 0 -> c_saturees = 7
# Iter 1 -> c_saturees = 10
# Iter 2 -> c_saturees = 10
# Iter 3 -> c_saturees = 12
# Iter 4 -> c_saturees = 12
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 20
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 87.0
# Iter 0 -> c_saturees = 6
# Iter 1 -> c_saturees = 8
# Iter 2 -> c_saturees = 8
# Iter 3 -> c_saturees = 8
# Iter 4 -> c_saturees = 8
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 21
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 107.0
# Iter 0 -> c_saturees = 6
# Iter 1 -> c_saturees = 8
# Iter 2 -> c_saturees = 8
# Iter 3 -> c_saturees = 9
# Iter 4 -> c_saturees = 9
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 22
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 72.0
# Iter 0 -> c_saturees = 8
# Iter 1 -> c_saturees = 8
# Iter 2 -> c_saturees = 10
# Iter 3 -> c_saturees = 10
# Iter 4 -> c_saturees = 10
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 23
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 66.0
# Iter 0 -> c_saturees = 10
# Iter 1 -> c_saturees = 10
# Iter 2 -> c_saturees = 10
# Iter 3 -> c_saturees = 10
# Iter 4 -> c_saturees = 10
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 24
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 92.0
# Iter 0 -> c_saturees = 7
# Iter 1 -> c_saturees = 8
# Iter 2 -> c_saturees = 8
# Iter 3 -> c_saturees = 8
# Iter 4 -> c_saturees = 8
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 25
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 73.0
# Iter 0 -> c_saturees = 7
# Iter 1 -> c_saturees = 7
# Iter 2 -> c_saturees = 7
# Iter 3 -> c_saturees = 7
# Iter 4 -> c_saturees = 7
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 26
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 86.0
# Iter 0 -> c_saturees = 7
# Iter 1 -> c_saturees = 8
# Iter 2 -> c_saturees = 8
# Iter 3 -> c_saturees = 8
# Iter 4 -> c_saturees = 8
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 27
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 86.0
# Iter 0 -> c_saturees = 5
# Iter 1 -> c_saturees = 5
# Iter 2 -> c_saturees = 5
# Iter 3 -> c_saturees = 5
# Iter 4 -> c_saturees = 5
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 28
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 91.0
# Iter 0 -> c_saturees = 10
# Iter 1 -> c_saturees = 10
# Iter 2 -> c_saturees = 10
# Iter 3 -> c_saturees = 10
# Iter 4 -> c_saturees = 10
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 29
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 80.0
# Iter 0 -> c_saturees = 7
# Iter 1 -> c_saturees = 7
# Iter 2 -> c_saturees = 9
# Iter 3 -> c_saturees = 9
# Iter 4 -> c_saturees = 9
# Nombre de contraintes ajoutées et non saturées : 0
# Test numéro : 30
# Solution trouvée à la tentative 1
# Valeur optimale de l'objectif : 80.0
# Iter 0 -> c_saturees = 10
# Iter 1 -> c_saturees = 13
# Iter 2 -> c_saturees = 13
# Iter 3 -> c_saturees = 13
# Iter 4 -> c_saturees = 13
# Nombre de contraintes ajoutées et non saturées : 0
# OK
