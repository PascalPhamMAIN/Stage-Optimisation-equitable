# %%
nb_tests = 1
time_max_sum = 0
time_max_min_cout_sum = 0
time_exact_sum = 0
ratio1_sum = 0
ratio2_sum = 0
ratio12_sum = 0

for i in range(nb_tests):
    print("Test numéro :", i+1)
    # %run arrondi_iteratif1.ipynb
    #time_max_moy = (i*time_max_moy + time_max)/(i+1)
    time_max_sum += time_max
    time_max_min_cout_sum += time_max_min_cout
    time_exact_sum += time_exact
    ratio1_sum += ratio1
    ratio2_sum += ratio2
    ratio12_sum += ratio12

time_max_moy = time_max_sum/nb_tests
time_max_min_cout_moy = time_max_min_cout_sum/nb_tests
time_exact_moy = time_exact_sum/nb_tests
ratio1_moy = ratio1_sum/nb_tests
ratio2_moy = ratio2_sum/nb_tests
ratio12_moy = ratio12_sum/nb_tests

print("-----RESULTATS FINAUX-----")
print("Temps moyen avec algo max 1:", time_max_moy)
print("Temps moyen avec algo max 2 :", time_max_min_cout_moy)
print("Temps moyen avec algo exact :", time_exact_moy)
print("Avec max 1, Ratio moyen de", ratio1_moy) # Recherche d'un facteur d'approximation
print("Avec max 2, Ratio moyen de", ratio2_moy) # Recherche d'un facteur d'approximation
print("Ratio max 1/max 2 de", ratio12_moy) # 1 : max, 2 : max avec min cout
# Out:
# Test numéro : 0
# val =  0.0 i,j : 0 0
# val =  0.0 i,j : 0 1
# val =  0.0 i,j : 0 2
# val =  1.0 i,j : 0 3
# val =  0.0 i,j : 0 4
# val =  0.0 i,j : 0 5
# val =  0.18070134657416478 i,j : 0 6
# val =  0.0 i,j : 0 7
# val =  0.0 i,j : 0 8
# val =  0.0 i,j : 0 9
# val =  0.0 i,j : 1 0
# val =  0.0 i,j : 1 1
# val =  0.0 i,j : 1 2
# val =  0.0 i,j : 1 3
# val =  0.0 i,j : 1 4
# val =  0.0 i,j : 1 5
# val =  0.38512241236922273 i,j : 1 6
# val =  0.0 i,j : 1 7
# val =  0.0 i,j : 1 8
# val =  1.0 i,j : 1 9
# val =  0.2982668578101991 i,j : 2 0
# val =  1.0 i,j : 2 1
# val =  1.0 i,j : 2 2
# val =  0.0 i,j : 2 3
# val =  1.0 i,j : 2 4
# val =  0.0 i,j : 2 5
# val =  0.0 i,j : 2 6
# val =  1.0 i,j : 2 7
# val =  0.0 i,j : 2 8
# val =  0.0 i,j : 2 9
# val =  0.7017331421898009 i,j : 3 0
# val =  0.0 i,j : 3 1
# val =  0.0 i,j : 3 2
# val =  0.0 i,j : 3 3
# val =  0.0 i,j : 3 4
# val =  0.0 i,j : 3 5
# val =  0.03483422073818207 i,j : 3 6
# val =  0.0 i,j : 3 7
# val =  1.0 i,j : 3 8
# ...
