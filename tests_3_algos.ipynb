# %%
nb_tests = 5

time_approx_o_sum = 0
time_exact_o_sum = 0
ratio_approx_o_sum = 0
time_approx_c_sum = 0
time_exact_c_sum = 0
ratio_approx_c_sum = 0
min_max_val_o1 = 1 # on cherche le plus petit sur les nb_tests pour C et O (en fait les 2 c'est tjrs la meme valeur)
min_max_val_c1 = 1
# il faudrait comparer ce min_max_val avec le 3eme modèle

for i in range(nb_tests):
    print("Test numéro :", i+1)
    # %run arrondi_iteratif.ipynb
    time_approx_o_sum += time_max
    time_exact_o_sum += time_exact
    ratio_approx_o_sum += ratio_max_o
    time_approx_c_sum += time_approx_c
    time_exact_c_sum += time_exact_c
    ratio_approx_c_sum += ratio_max_c
    if min_max_val_o < min_max_val_o1:
        min_max_val_o1 = min_max_val_o
    if min_max_val_c < min_max_val_c1:
        min_max_val_c1 = min_max_val_c

time_approx_o_moy = time_approx_o_sum/nb_tests
time_exact_o_moy = time_exact_o_sum/nb_tests
ratio_approx_o_moy = ratio_approx_o_sum/nb_tests

time_approx_c_moy = time_approx_c_sum/nb_tests
time_exact_c_moy = time_exact_c_sum/nb_tests
ratio_approx_c_moy = ratio_approx_c_sum/nb_tests

print("\n-----RESULTATS FINAUX-----")
print("O-MIP : Temps moyen avec algo approché :", time_approx_o_moy)
print("C-MIP : Temps moyen avec algo approché :", time_approx_c_moy)
print("O-MIP : Temps moyen avec algo exact :", time_exact_o_moy)
print("C-MIP : Temps moyen avec algo exact :", time_exact_c_moy)
print("O-MIP : Ratio moyen de", ratio_approx_o_moy)
print("C-MIP : Ratio moyen de", ratio_approx_c_moy)
print("min_max_val(O) sur l'ensemble des tests :", min_max_val_o1)
print("min_max_val(C) sur l'ensemble des tests :", min_max_val_c1)
# Out:
# Test numéro : 1
# Nombre d'itérations prises par Gurobi : 5988.0
# time_approx(O) : 11.841702461242676
# val_approx_o : 70320.000000
# min_max_val(O) : 0.22123893805309736
# Cout total : 2079.0
# time_exact(O) : 111.10188961029053
# val_exact_o : 69442.000000
# time_exact(C) : 321.82459235191345
# val_exact_c : 69442.000000
# Nombre d'itérations prises par Gurobi : 6973.0
# time_approx(C) : 8.55968713760376
# val_approx_c : 70320.000000
# min_max_val(C) : 0.22123893805309736
# Cout total : 2079.0
# O-MIP, Ratio de 1.0126436450563059
# C-MIP, Ratio de 1.0126436450563059
# ------
# Test numéro : 2
# Nombre d'itérations prises par Gurobi : 6564.0
# time_approx(O) : 15.269984006881714
# val_approx_o : 61687.000000
# min_max_val(O) : 0.4625652002193228
# Cout total : 1941.0
# time_exact(O) : 184.4721281528473
# val_exact_o : 60723.000000
# time_exact(C) : 427.7016339302063
# val_exact_c : 60723.000000
# Nombre d'itérations prises par Gurobi : 7921.0
# time_approx(C) : 8.241212129592896
# val_approx_c : 61687.000000
# min_max_val(C) : 0.46256520021932157
# Cout total : 1941.0
# O-MIP, Ratio de 1.0158753684765245
# C-MIP, Ratio de 1.0158753684765245
# ------
# Test numéro : 3
# Nombre d'itérations prises par Gurobi : 5827.0
# time_approx(O) : 14.937824010848999
# val_approx_o : 82094.000000
# min_max_val(O) : 0.2112676056338028
# Cout total : 2324.0
# time_exact(O) : 183.949857711792
# val_exact_o : 77622.000000
# time_exact(C) : 198.6233570575714
# val_exact_c : 77622.000000
# Nombre d'itérations prises par Gurobi : 7347.0
# time_approx(C) : 8.390882730484009
# val_approx_c : 82094.000000
# min_max_val(C) : 0.2112676056338028
# Cout total : 2324.0
# O-MIP, Ratio de 1.0576125325294374
# C-MIP, Ratio de 1.0576125325294374
# ------
# Test numéro : 4
# Nombre d'itérations prises par Gurobi : 5821.0
# time_approx(O) : 15.041501998901367
# val_approx_o : 80106.000000
# min_max_val(O) : 0.2
# Cout total : 2353.0
# time_exact(O) : 373.3888826370239
# val_exact_o : 77194.000000
# time_exact(C) : 466.5131604671478
# val_exact_c : 77194.000000
# Nombre d'itérations prises par Gurobi : 6332.0
# time_approx(C) : 8.112690925598145
# val_approx_c : 80106.000000
# min_max_val(C) : 0.19999999999999973
# Cout total : 2353.0
# O-MIP, Ratio de 1.0377231391040755
# C-MIP, Ratio de 1.0377231391040755
# ------
# Test numéro : 5
# Nombre d'itérations prises par Gurobi : 5531.0
# time_approx(O) : 14.614522933959961
# val_approx_o : 64107.000000
# min_max_val(O) : 0.34579439252336447
# Cout total : 1905.0
# time_exact(O) : 141.55742621421814
# val_exact_o : 61207.000000
# time_exact(C) : 101.44042634963989
# val_exact_c : 61207.000000
# Nombre d'itérations prises par Gurobi : 7988.0
# time_approx(C) : 8.364167928695679
# val_approx_c : 64107.000000
# min_max_val(C) : 0.34579439252336447
# Cout total : 1905.0
# O-MIP, Ratio de 1.0473802016109268
# C-MIP, Ratio de 1.0473802016109268
# ------
#
# -----RESULTATS FINAUX-----
# O-MIP : Temps moyen avec algo approché : 14.341107082366943
# C-MIP : Temps moyen avec algo approché : 8.333728170394897
# O-MIP : Temps moyen avec algo exact : 198.89403686523437
# C-MIP : Temps moyen avec algo exact : 303.2206340312958
# O-MIP : Ratio moyen de 1.034246977355454
# C-MIP : Ratio moyen de 1.034246977355454
# min_max_val(O) sur l'ensemble des tests : 0.2
# min_max_val(C) sur l'ensemble des tests : 0.19999999999999973
