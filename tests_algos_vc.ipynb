# %%
nb_tests = 10
time_approx_o_sum = 0
#time_exact_o_sum = 0
ratio_approx_o_sum = 0
time_approx_c_sum = 0
#time_exact_c_sum = 0
ratio_approx_c_sum = 0
#time_approx_3e_sum = 0
##time_exact_3e_sum = 0
#ratio_approx_3e_sum = 0
time_approx_3e_v2_sum = 0
#time_exact_3e_sum = 0
ratio_approx_3e_v2_sum = 0

sum_it_frac_o = 0
sum_it_frac_c = 0
sum_it_frac_3e = 0

for i in range(nb_tests):
    print("Test numéro :", i+1)
    # %run vertex_cover_equitable.ipynb
    time_approx_o_sum += time_approx
    #time_exact_o_sum += time_exact
    ratio_approx_o_sum += ratio_o
    
    time_approx_c_sum += time_approx_chassein
    #time_exact_c_sum += time_exact_c
    ratio_approx_c_sum += ratio_c
    
    #time_approx_3e_sum += time_approx_3e_mod
    ##time_exact_3e_sum += time_exact_3e
    #ratio_approx_3e_sum += ratio_3e

    time_approx_3e_v2_sum += time_approx_3e_v2
    #time_exact_3e_v2_sum += time_exact_3e
    ratio_approx_3e_v2_sum += ratio_3e_v2

    sum_it_frac_o += it_frac_o
    sum_it_frac_c += it_frac_c
    sum_it_frac_3e += it_frac_3e

time_approx_o_moy = time_approx_o_sum/nb_tests
#time_exact_o_moy = time_exact_o_sum/nb_tests
ratio_approx_o_moy = ratio_approx_o_sum/nb_tests

time_approx_c_moy = time_approx_c_sum/nb_tests
#time_exact_c_moy = time_exact_c_sum/nb_tests
ratio_approx_c_moy = ratio_approx_c_sum/nb_tests

#time_approx_3e_moy = time_approx_3e_sum/nb_tests
##time_exact_3e_moy = time_exact_3e_sum/nb_tests
#ratio_approx_3e_moy = ratio_approx_3e_sum/nb_tests

time_approx_3e_v2_moy = time_approx_3e_v2_sum/nb_tests
#time_exact_3e_v2_moy = time_exact_3e_sum/nb_tests
ratio_approx_3e_v2_moy = ratio_approx_3e_v2_sum/nb_tests

moy_it_frac_o = sum_it_frac_o/nb_tests
moy_it_frac_c = sum_it_frac_c/nb_tests
moy_it_frac_3e = sum_it_frac_3e/nb_tests

print("\n-----RESULTATS FINAUX-----")
print("O-MIP : Temps moyen avec algo approché :", time_approx_o_moy)
print("C-MIP : Temps moyen avec algo approché :", time_approx_c_moy)
#print("3eme modele : Temps moyen avec algo approché :", time_approx_3e_moy)
print("3eme modele avec prob de séparation : Temps moyen avec algo approché :", time_approx_3e_v2_moy)
#print("O-MIP : Temps moyen avec algo exact :", time_exact_o_moy)
#print("C-MIP : Temps moyen avec algo exact :", time_exact_c_moy)
##print("3eme modele : Temps moyen avec algo exact :", time_exact_3e_moy)
##print("prob de séparation, 3eme modele : Temps moyen avec algo exact :", time_exact_3e_v2_moy)
print("O-MIP : Ratio moyen de", ratio_approx_o_moy)
print("C-MIP : Ratio moyen de", ratio_approx_c_moy)
#print("3eme modele : Ratio moyen de", ratio_approx_3e_moy)
print("3eme modele avec prob de séparation : Ratio moyen de", ratio_approx_3e_v2_moy)

print("moy it_frac(O) sur l'ensemble des tests :", moy_it_frac_o)
print("moy it_frac(C) sur l'ensemble des tests :", moy_it_frac_c)
print("moy it_frac(3e) sur l'ensemble des tests :", moy_it_frac_3e)
# Out:
# Test numéro : 1
# Nombre d'arêtes dans le graphe : 325
# Nombre d'itérations prises par Gurobi : 2532.0
# val_approx_o : 788875.000000
# min_max_val_o = 0.5
# time_approx(O) : 0.5407304763793945
# it_frac(O) = 78
# val_exact_o : 702610.000000
# val_exact_c : 702610.000000
# Nombre d'itérations prises par Gurobi : 2766.0
# val_approx_c : 788875.000000
# min_max_val_c : 0.5
# time_approx(C) : 0.48667120933532715
# it_frac(C) = 78
# Terminé. Nombre total d'itérations Gurobi: 7100.0
# time_approx_3e_v2 : 0.8447961807250977
# min_max_val_3e_v2 : 0.5
# Valeur de l'objectif: 385226.0
# 2*val_new_mod : 770452.000000
# it_frac(3e) = 78
# O-MIP, Ratio de : 1.1227779280112722
# C-MIP, Ratio de : 1.1227779280112722
# new mod avec problème de séparation, Ratio de : 1.0965571227281137
# ------
# Test numéro : 2
# Nombre d'arêtes dans le graphe : 329
# Nombre d'itérations prises par Gurobi : 2392.0
# val_approx_o : 751795.000000
# min_max_val_o = 0.5
# time_approx(O) : 0.5338757038116455
# it_frac(O) = 83
# val_exact_o : 671392.000000
# val_exact_c : 671392.000000
# Nombre d'itérations prises par Gurobi : 2441.0
# val_approx_c : 751795.000000
# min_max_val_c : 0.5
# time_approx(C) : 0.4658799171447754
# it_frac(C) = 83
# Terminé. Nombre total d'itérations Gurobi: 6145.0
# time_approx_3e_v2 : 0.6698184013366699
# min_max_val_3e_v2 : 0.5
# Valeur de l'objectif: 372552.5
# 2*val_new_mod : 745105.000000
# it_frac(3e) = 82
# O-MIP, Ratio de : 1.1197556717982937
# C-MIP, Ratio de : 1.1197556717982937
# new mod avec problème de séparation, Ratio de : 1.1097912992707688
# ------
# Test numéro : 3
# Nombre d'arêtes dans le graphe : 327
# Nombre d'itérations prises par Gurobi : 2904.0
# val_approx_o : 807954.000000
# min_max_val_o = 0.5
# time_approx(O) : 0.595299482345581
# it_frac(O) = 83
# val_exact_o : 712171.000000
# val_exact_c : 712171.000000
# Nombre d'itérations prises par Gurobi : 3156.0
# val_approx_c : 807954.000000
# min_max_val_c : 0.5
# time_approx(C) : 0.4912385940551758
# it_frac(C) = 83
# Terminé. Nombre total d'itérations Gurobi: 7049.0
# time_approx_3e_v2 : 0.9001264572143555
# min_max_val_3e_v2 : 0.5
# Valeur de l'objectif: 394471.0
# 2*val_new_mod : 788942.000000
# it_frac(3e) = 82
# O-MIP, Ratio de : 1.134494384073488
# C-MIP, Ratio de : 1.134494384073488
# new mod avec problème de séparation, Ratio de : 1.1077985483823407
# ------
# Test numéro : 4
# Nombre d'arêtes dans le graphe : 321
# Nombre d'itérations prises par Gurobi : 2452.0
# val_approx_o : 778824.000000
# min_max_val_o = 0.5
# time_approx(O) : 0.5614328384399414
# it_frac(O) = 81
# val_exact_o : 694758.000000
# val_exact_c : 694758.000000
# Nombre d'itérations prises par Gurobi : 2522.0
# val_approx_c : 778824.000000
# min_max_val_c : 0.5
# time_approx(C) : 0.4770340919494629
# it_frac(C) = 81
# Terminé. Nombre total d'itérations Gurobi: 5891.0
# time_approx_3e_v2 : 0.6651725769042969
# min_max_val_3e_v2 : 0.5
# Valeur de l'objectif: 390453.5
# 2*val_new_mod : 780907.000000
# it_frac(3e) = 82
# O-MIP, Ratio de : 1.1210004058967296
# C-MIP, Ratio de : 1.1210004058967296
# new mod avec problème de séparation, Ratio de : 1.1239985721646961
# ------
# Test numéro : 5
# Nombre d'arêtes dans le graphe : 300
# Nombre d'itérations prises par Gurobi : 2801.0
# val_approx_o : 762137.000000
# min_max_val_o = 0.5
# time_approx(O) : 0.529111385345459
# it_frac(O) = 81
# val_exact_o : 692777.000000
# val_exact_c : 692777.000000
# Nombre d'itérations prises par Gurobi : 2991.0
# val_approx_c : 762137.000000
# min_max_val_c : 0.5
# time_approx(C) : 0.5252106189727783
# it_frac(C) = 81
# Terminé. Nombre total d'itérations Gurobi: 6826.0
# time_approx_3e_v2 : 0.8493669033050537
# min_max_val_3e_v2 : 0.5
# Valeur de l'objectif: 381068.5
# 2*val_new_mod : 762137.000000
# it_frac(3e) = 80
# O-MIP, Ratio de : 1.1001187972464443
# C-MIP, Ratio de : 1.1001187972464443
# new mod avec problème de séparation, Ratio de : 1.1001187972464443
# ------
# Test numéro : 6
# Nombre d'arêtes dans le graphe : 337
# Nombre d'itérations prises par Gurobi : 2754.0
# val_approx_o : 778322.000000
# min_max_val_o = 0.5
# time_approx(O) : 0.5373759269714355
# it_frac(O) = 76
# val_exact_o : 723167.000000
# val_exact_c : 723167.000000
# Nombre d'itérations prises par Gurobi : 3000.0
# val_approx_c : 778322.000000
# min_max_val_c : 0.5
# time_approx(C) : 0.500638484954834
# it_frac(C) = 76
# Terminé. Nombre total d'itérations Gurobi: 7963.0
# time_approx_3e_v2 : 0.9517877101898193
# min_max_val_3e_v2 : 0.5
# Valeur de l'objectif: 389161.0
# 2*val_new_mod : 778322.000000
# it_frac(3e) = 79
# O-MIP, Ratio de : 1.076268690357829
# C-MIP, Ratio de : 1.076268690357829
# new mod avec problème de séparation, Ratio de : 1.076268690357829
# ------
# Test numéro : 7
# Nombre d'arêtes dans le graphe : 319
# Nombre d'itérations prises par Gurobi : 2411.0
# val_approx_o : 828767.000000
# min_max_val_o = 0.5
# time_approx(O) : 0.5369868278503418
# it_frac(O) = 81
# val_exact_o : 725625.000000
# val_exact_c : 725625.000000
# Nombre d'itérations prises par Gurobi : 2646.0
# val_approx_c : 828767.000000
# min_max_val_c : 0.5
# time_approx(C) : 0.4490034580230713
# it_frac(C) = 81
# Terminé. Nombre total d'itérations Gurobi: 6860.0
# time_approx_3e_v2 : 0.777742862701416
# min_max_val_3e_v2 : 0.5
# Valeur de l'objectif: 404596.0
# 2*val_new_mod : 809192.000000
# it_frac(3e) = 79
# O-MIP, Ratio de : 1.1421422911283377
# C-MIP, Ratio de : 1.1421422911283377
# new mod avec problème de séparation, Ratio de : 1.1151655469422912
# ------
# Test numéro : 8
# Nombre d'arêtes dans le graphe : 332
# Nombre d'itérations prises par Gurobi : 3034.0
# val_approx_o : 691580.000000
# min_max_val_o = 0.5
# time_approx(O) : 0.5360708236694336
# it_frac(O) = 79
# val_exact_o : 637178.000000
# val_exact_c : 637178.000000
# Nombre d'itérations prises par Gurobi : 3190.0
# val_approx_c : 691580.000000
# min_max_val_c : 0.5
# time_approx(C) : 0.47733068466186523
# it_frac(C) = 79
# Terminé. Nombre total d'itérations Gurobi: 6668.0
# time_approx_3e_v2 : 0.8123674392700195
# min_max_val_3e_v2 : 0.5
# Valeur de l'objectif: 345912.0
# 2*val_new_mod : 691824.000000
# it_frac(3e) = 80
# O-MIP, Ratio de : 1.0853795956545895
# C-MIP, Ratio de : 1.0853795956545895
# new mod avec problème de séparation, Ratio de : 1.085762534174124
# ------
# Test numéro : 9
# Nombre d'arêtes dans le graphe : 321
# Nombre d'itérations prises par Gurobi : 2451.0
# val_approx_o : 777724.000000
# min_max_val_o = 0.5
# time_approx(O) : 0.5078954696655273
# it_frac(O) = 83
# val_exact_o : 704394.000000
# val_exact_c : 704394.000000
# Nombre d'itérations prises par Gurobi : 2708.0
# val_approx_c : 777724.000000
# min_max_val_c : 0.5
# time_approx(C) : 0.43672776222229004
# it_frac(C) = 83
# Terminé. Nombre total d'itérations Gurobi: 5530.0
# time_approx_3e_v2 : 0.6176183223724365
# min_max_val_3e_v2 : 0.5
# Valeur de l'objectif: 386280.0
# 2*val_new_mod : 772560.000000
# it_frac(3e) = 82
# O-MIP, Ratio de : 1.1041036692532873
# C-MIP, Ratio de : 1.1041036692532873
# new mod avec problème de séparation, Ratio de : 1.0967725449109447
# ------
# Test numéro : 10
# Nombre d'arêtes dans le graphe : 338
# Nombre d'itérations prises par Gurobi : 2836.0
# val_approx_o : 744173.000000
# min_max_val_o = 0.5
# time_approx(O) : 0.5601890087127686
# it_frac(O) = 83
# val_exact_o : 691165.000000
# val_exact_c : 691165.000000
# Nombre d'itérations prises par Gurobi : 2804.0
# val_approx_c : 744173.000000
# min_max_val_c : 0.5
# time_approx(C) : 0.4734914302825928
# it_frac(C) = 82
# Terminé. Nombre total d'itérations Gurobi: 6166.0
# time_approx_3e_v2 : 0.7218632698059082
# min_max_val_3e_v2 : 0.5
# Valeur de l'objectif: 376155.5
# 2*val_new_mod : 752311.000000
# it_frac(3e) = 83
# O-MIP, Ratio de : 1.076693698320951
# C-MIP, Ratio de : 1.076693698320951
# new mod avec problème de séparation, Ratio de : 1.0884680213841846
# ------
#
# -----RESULTATS FINAUX-----
# O-MIP : Temps moyen avec algo approché : 0.5438967943191528
# C-MIP : Temps moyen avec algo approché : 0.4783226251602173
# 3eme modele avec prob de séparation : Temps moyen avec algo approché : 0.7810660123825073
# O-MIP : Ratio moyen de 1.1082735131741224
# C-MIP : Ratio moyen de 1.1082735131741224
# 3eme modele avec prob de séparation : Ratio moyen de 1.1000701677561735
# moy it_frac(O) sur l'ensemble des tests : 80.8
# moy it_frac(C) sur l'ensemble des tests : 80.7
# moy it_frac(3e) sur l'ensemble des tests : 80.7
