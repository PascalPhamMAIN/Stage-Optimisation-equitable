# %%
nb_tests = 30
time_approx_o_sum = 0
#time_exact_o_sum = 0
ratio_approx_o_sum = 0
time_approx_c_sum = 0
#time_exact_c_sum = 0
ratio_approx_c_sum = 0
#time_approx_3e_sum = 0
##time_exact_3e_sum = 0
#ratio_approx_3e_sum = 0
time_approx_3e_v2_sum = 0
#time_exact_3e_sum = 0
ratio_approx_3e_v2_sum = 0

sum_it_frac_o = 0
sum_it_frac_c = 0
sum_it_frac_3e = 0

for i in range(nb_tests):
    print("Test numéro :", i+1)
    # %run vertex_cover_equitable.ipynb
    time_approx_o_sum += time_approx
    #time_exact_o_sum += time_exact
    ratio_approx_o_sum += ratio_o
    
    time_approx_c_sum += time_approx_chassein
    #time_exact_c_sum += time_exact_c
    ratio_approx_c_sum += ratio_c
    
    #time_approx_3e_sum += time_approx_3e_mod
    ##time_exact_3e_sum += time_exact_3e
    #ratio_approx_3e_sum += ratio_3e

    time_approx_3e_v2_sum += time_approx_3e_v2
    #time_exact_3e_v2_sum += time_exact_3e
    ratio_approx_3e_v2_sum += ratio_3e_v2

    sum_it_frac_o += it_frac_o
    sum_it_frac_c += it_frac_c
    sum_it_frac_3e += it_frac_3e

time_approx_o_moy = time_approx_o_sum/nb_tests
#time_exact_o_moy = time_exact_o_sum/nb_tests
ratio_approx_o_moy = ratio_approx_o_sum/nb_tests

time_approx_c_moy = time_approx_c_sum/nb_tests
#time_exact_c_moy = time_exact_c_sum/nb_tests
ratio_approx_c_moy = ratio_approx_c_sum/nb_tests

#time_approx_3e_moy = time_approx_3e_sum/nb_tests
##time_exact_3e_moy = time_exact_3e_sum/nb_tests
#ratio_approx_3e_moy = ratio_approx_3e_sum/nb_tests

time_approx_3e_v2_moy = time_approx_3e_v2_sum/nb_tests
#time_exact_3e_v2_moy = time_exact_3e_sum/nb_tests
ratio_approx_3e_v2_moy = ratio_approx_3e_v2_sum/nb_tests

moy_it_frac_o = sum_it_frac_o/nb_tests
moy_it_frac_c = sum_it_frac_c/nb_tests
moy_it_frac_3e = sum_it_frac_3e/nb_tests

print("\n-----RESULTATS FINAUX-----")
print("O-MIP : Temps moyen avec algo approché :", time_approx_o_moy)
print("C-MIP : Temps moyen avec algo approché :", time_approx_c_moy)
#print("3eme modele : Temps moyen avec algo approché :", time_approx_3e_moy)
print("3eme modele avec prob de séparation : Temps moyen avec algo approché :", time_approx_3e_v2_moy)
#print("O-MIP : Temps moyen avec algo exact :", time_exact_o_moy)
#print("C-MIP : Temps moyen avec algo exact :", time_exact_c_moy)
##print("3eme modele : Temps moyen avec algo exact :", time_exact_3e_moy)
##print("prob de séparation, 3eme modele : Temps moyen avec algo exact :", time_exact_3e_v2_moy)
print("O-MIP : Ratio moyen de", ratio_approx_o_moy)
print("C-MIP : Ratio moyen de", ratio_approx_c_moy)
#print("3eme modele : Ratio moyen de", ratio_approx_3e_moy)
print("3eme modele avec prob de séparation : Ratio moyen de", ratio_approx_3e_v2_moy)

print("moy it_frac(O) sur l'ensemble des tests :", moy_it_frac_o)
print("moy it_frac(C) sur l'ensemble des tests :", moy_it_frac_c)
print("moy it_frac(3e) sur l'ensemble des tests :", moy_it_frac_3e)
# Out:
# Test numéro : 1
# Nombre d'arêtes dans le graphe : 215
# Nombre d'itérations prises par Gurobi : 5025.0
# val_approx_o : 1777875.000000
# min_max_val_o = 0.5
# time_approx(O) : 1.739501953125
# it_frac(O) = 125
# val_exact_o : 1537589.000000
# val_exact_c : 1537589.000000
# Nombre d'itérations prises par Gurobi : 5214.0
# val_approx_c : 1777875.000000
# min_max_val_c : 0.5
# time_approx(C) : 1.413078784942627
# it_frac(C) = 125
# Terminé. Nombre total d'itérations Gurobi: 38559.0
# time_approx_3e_v2 : 5.232595443725586
# min_max_val_3e_v2 : 0.5
# Valeur de l'objectif: 896947.5
# 2*val_new_mod : 1793895.000000
# it_frac(3e) = 137
# O-MIP, Ratio de : 1.1562745311003135
# C-MIP, Ratio de : 1.1562745311003135
# new mod avec problème de séparation, Ratio de : 1.1666934401846007
# ------
# Test numéro : 2
# Nombre d'arêtes dans le graphe : 212
# Nombre d'itérations prises par Gurobi : 6183.0
# val_approx_o : 1819174.000000
# min_max_val_o = 0.5
# time_approx(O) : 1.6213436126708984
# it_frac(O) = 137
